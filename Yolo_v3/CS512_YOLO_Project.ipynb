# %%
pip install -r /content/requirements.txt
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from -r /content/requirements.txt (line 1)) (2.5.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from -r /content/requirements.txt (line 2)) (1.26.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from -r /content/requirements.txt (line 3)) (3.8.0)
# Collecting Counter (from -r /content/requirements.txt (line 4))
#   Downloading Counter-1.0.0.tar.gz (5.2 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from -r /content/requirements.txt (line 5)) (0.20.1+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from -r /content/requirements.txt (line 6)) (4.66.6)
# Collecting typing (from -r /content/requirements.txt (line 7))
#   Downloading typing-3.7.4.3.tar.gz (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 1.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ERROR: Ignored the following versions that require a different python version: 3.10.0.0 Requires-Python >=2.7, !=3.0.*, !=3.1.*, !=3.2.*, !=3.3.*, <3.5; 3.7.4.2 Requires-Python >=2.7, !=3.0.*, !=3.1.*, !=3.2.*, !=3.3.*, <3.5
# ERROR: Could not find a version that satisfies the requirement os (from versions: none)
# ERROR: No matching distribution found for os

# %%
##################################################             YOLO         ##########################################################################

# ------------------------------------------------       Defining the Model           ----------------------------------------------------------------

import torch
import torch.nn as nn

# Tuples are defined as (kernel_size, filters, stride, padding), all the layers are designed exactly as described in the original paper.

Yolo_configuration = [
    (7, 64, 2, 3),        # (7, 64, 2, 3) indicates 7*7 kernel, 64 output filter, stride of 2 and 3 padding
    "M",                  # maxpooling layer
    (3, 192, 1, 1),       # 3*3 kernel, 192 output filters, stride of 1 and 1 padding
    "M",                  # maxpooling layer with stride 2x2 and kernel 2x2
    (1, 128, 1, 0),       # 1*1 kernel, 128 output filters, stride of 1 and 0 padding
    (3, 256, 1, 1),       # 3*3 kernel, 192 output filters, stride of 1 and 1 padding
    (1, 256, 1, 0),       # 3*3 kernel, 192 output filters, stride of 1 and 1 padding
    (3, 512, 1, 1),       # 3*3 kernel, 192 output filters, stride of 1 and 1 padding
    "M",                  # maxpooling layer
    [(1, 256, 1, 0), (3, 512, 1, 1), 4],    # 4 layers of 1*1 kernels, 256 output filters, 1 stride and 3*3 kernels, 512 output filters, 1 stride and 1 padding
    (1, 512, 1, 0),                         # 1*1 kernels, 512 output filters, 1 stride
    (3, 1024, 1, 1),                        # 3*3 kernels, 1024 output filters, 1 stride and 1 padding
    "M",                                    # maxpooling layer
    [(1, 512, 1, 0), (3, 1024, 1, 1), 2],   # 2 layers of 1*1 kernels, 512 output filters, 1 stride and 3*3 kernels, 1024 output filters, 1 stride and 1 padding
    (3, 1024, 1, 1),                        # 3*3 kernels, 1024 output filters, 1 stride and 1 padding
    (3, 1024, 2, 1),                        # 3*3 kernels, 1024 output filters, 2 stride and 1 padding
    (3, 1024, 1, 1),                        # 3*3 kernels, 1024 output filters, 1 stride and 1 padding
    (3, 1024, 1, 1),                        # 3*3 kernels, 1024 output filters, 1 stride and 1 padding
]

# ---------------------------------------  Defining the CNN Blocks   -------------------------------------------------------------
class CNNLayer(nn.Module):
    def __init__(self, input_channels, output_channels, **kwargs):
        """
        Args:
            input_channels (int): Number of input channels.
            output_channels (int): Number of output channels (filters).
            kernel_size (int): Size of the convolutional kernel.
            stride (int): Stride for the convolution.
            padding (int): Padding for the convolution.
        """
        super(CNNLayer, self).__init__()
        # Convolutional layer with no bias (bias=False for BatchNorm compatibility)
        self.conv = nn.Conv2d(input_channels, output_channels, bias=False, **kwargs)
        # Batch normalization layer to stabilize training
        self.batchnorm = nn.BatchNorm2d(output_channels)
        # Leaky ReLU activation function
        self.leakyrelu = nn.LeakyReLU(0.1)

    def forward(self, x):
        """
        Forward pass.
        Args:
            x (torch.Tensor): Input tensor.
        Returns:
            torch.Tensor: Output after applying Conv2D, BatchNorm, and LeakyReLU.
        """
        x = self.conv(x)         # convolution
        x = self.batchnorm(x)    # batch normalization
        x = self.leakyrelu(x)    # LeakyReLU activation
        return x

# -----------------------------------------------------------------------------------------------------------------------------------------

# ---------------------------------------  Defining the YOLO architecture   -------------------------------------------------------------

class YoloVersion1(nn.Module):
    def __init__(self, input_channels=3, **kwargs):
        """
        Initializing the YOLO1 model.

        Args:
            input_channels: Number of input channels (3 - RGB images).
            **kwargs: Additional parameters for fully connected layer creation.
        """
        super(YoloVersion1, self).__init__()
        self.architecture = Yolo_configuration    # Yolo configuration
        self.input_channels = input_channels       # Initial input channels
        self.darknet = self.create_cnn_layers(self.architecture)   # Convolutional layers
        self.fcs = self.create_fully_connected_layers(**kwargs)      # Fully connected layers

    def forward(self, x):
        """
        Forward pass through the YOLO.

        Args:
            x (torch.Tensor): Input image tensor.

        Returns:
            torch.Tensor: Output after passing through the model.
        """
        x = self.darknet(x)  # Passing through convolutional layers
        x = torch.flatten(x, start_dim=1)  # Flattening for fully connected layers
        return self.fcs(x)  # Passing through fully connected layers

    def create_cnn_layers(self, architecture):
        """
        Creating the convolutional layers of the YOLO model.

        Args:
            architecture: Configuration of the convolutional layers.

        Returns:
            nn.Sequential: A sequential container of the convolutional layers.
        """
        layers = []
        input_channels = self.input_channels

        for layer in architecture:
            if isinstance(layer, tuple):  # Standard convolutional layer
                kernel_size, filters, stride, padding = layer
                layers.append(
                    CNNLayer(
                        input_channels, filters,
                        kernel_size=kernel_size, stride=stride, padding=padding
                    )
                )
                input_channels = filters  # Updating the input channels for the next layer

            elif layer == "M":  # Max pooling layer
                layers.append(nn.MaxPool2d(kernel_size=(2, 2), stride=(2, 2)))

            elif isinstance(layer, list):  # Repeated blocks of convolutional layers
                conv1, conv2, num_repeats = layer
                for _ in range(num_repeats):
                    # First convolution in the repeated block
                    layers.append(
                        CNNLayer(
                            input_channels, conv1[1],
                            kernel_size=conv1[0], stride=conv1[2], padding=conv1[3]
                        )
                    )
                    # Second convolution in the repeated block
                    layers.append(
                        CNNLayer(
                            conv1[1], conv2[1],
                            kernel_size=conv2[0], stride=conv2[2], padding=conv2[3]
                        )
                    )
                    input_channels = conv2[1]  # Updating input channels after each block

        return nn.Sequential(*layers)  # sequential container

    def create_fully_connected_layers(self, split_size, num_boxes, num_classes):
        """
        The fully connected layers of the YOLO model.

        Args:
            **kwargs: Parameters for the fully connected layers (e.g., output size).

        Returns:
            nn.Sequential: A sequential container of the fully connected layers.
        """
        S, B, C = split_size, num_boxes, num_classes

        # Below code is as defined in the original paper
        return nn.Sequential(
            nn.Flatten(),
            nn.Linear(1024 * S * S, 496),
            nn.Dropout(0.0),
            nn.LeakyReLU(0.1),
            nn.Linear(496, S * S * (C + B * 5)),
        )

# %%
# --------------------------      Intersection over Union (IoU),Non-Maximum Suppression (NMS),Mean Average Precision (mAP)    ----------------------
import torch
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from collections import Counter

def calculate_iou(predicted_boxes, target_boxes, box_format="midpoint"):
    """
    Intersection over Union (IoU) between predicted and target bounding boxes.

    predicted_boxes (torch.Tensor): Predicted bounding boxes (BATCH_SIZE, 4)
        target_boxes (torch.Tensor): Target bounding boxes (BATCH_SIZE, 4)
        box_format (str): Format of bounding boxes - "midpoint" or "corners"

    Returns:
        torch.Tensor: IoU values for all examples
    """

    if box_format == "midpoint":
        # Converting from (x, y, w, h) to (x1, y1, x2, y2)
        pred_x1 = predicted_boxes[..., 0:1] - predicted_boxes[..., 2:3] / 2
        pred_y1 = predicted_boxes[..., 1:2] - predicted_boxes[..., 3:4] / 2
        pred_x2 = predicted_boxes[..., 0:1] + predicted_boxes[..., 2:3] / 2
        pred_y2 = predicted_boxes[..., 1:2] + predicted_boxes[..., 3:4] / 2
        target_x1 = target_boxes[..., 0:1] - target_boxes[..., 2:3] / 2
        target_y1 = target_boxes[..., 1:2] - target_boxes[..., 3:4] / 2
        target_x2 = target_boxes[..., 0:1] + target_boxes[..., 2:3] / 2
        target_y2 = target_boxes[..., 1:2] + target_boxes[..., 3:4] / 2

    if box_format == "corners":
        # Boxes are already in (x1, y1, x2, y2) format
        pred_x1 = predicted_boxes[..., 0:1]
        pred_y1 = predicted_boxes[..., 1:2]
        pred_x2 = predicted_boxes[..., 2:3]
        pred_y2 = predicted_boxes[..., 3:4]  # (N, 1)
        target_x1 = target_boxes[..., 0:1]
        target_y1 = target_boxes[..., 1:2]
        target_x2 = target_boxes[..., 2:3]
        target_y2 = target_boxes[..., 3:4]

    # Calculating intersection coordinates
    intersection_x1 = torch.max(pred_x1, target_x1)
    intersection_y1 = torch.max(pred_y1, target_y1)
    intersection_x2 = torch.min(pred_x2, target_x2)
    intersection_y2 = torch.min(pred_y2, target_y2)

    # .clamp(0) is for the case when they do not intersect
    intersection_area = (intersection_x2 - intersection_x1).clamp(0) * (intersection_y2 - intersection_y1).clamp(0)

    # Calculating box areas
    pred_area = abs((pred_x2 - pred_x1) * (pred_y2 - pred_y1))
    target_area = abs((target_x2 - target_x1) * (target_y2 - target_y1))

    union_area = pred_area + target_area - intersection_area

    return intersection_area / (union_area + 1e-6) # Adding small epsilon to avoid division by zero


def non_max_suppression(bounding_boxes, iou_threshold, confidence_threshold, box_format="corners"):
    """
    Applies Non-Maximum Suppression (NMS) to a list of bounding boxes.

    Args:
        bounding_boxes (List[List[float]]): List of bounding boxes, each specified as
            [class_prediction, confidence_score, x1, y1, x2, y2]
        iou_threshold (float): IoU threshold for considering overlapping boxes
        confidence_threshold (float): Threshold to filter low-confidence predictions
        box_format (str): Format of bounding boxes - "midpoint" or "corners"

    Returns:
        List[List[float]]: Filtered bounding boxes after applying NMS
    """

    assert isinstance(bounding_boxes, list)

    # Filtering out low-confidence predictions
    filtered_boxes = [box for box in bounding_boxes if box[1] > confidence_threshold]
    # Sorting boxes by confidence score in descending order
    sorted_boxes = sorted(filtered_boxes, key=lambda x: x[1], reverse=True)
    nms_result = []

    while sorted_boxes:
        chosen_box = sorted_boxes.pop(0)
        # Filtering out boxes with high IoU overlap
        sorted_boxes = [
            box for box in sorted_boxes
            if box[0] != chosen_box[0]
            or calculate_iou(
                torch.tensor(chosen_box[2:]),
                torch.tensor(box[2:]),
                box_format=box_format,
            )
            < iou_threshold
        ]

        nms_result.append(chosen_box)

    return nms_result


def calculate_mean_average_precision(
    predicted_boxes, ground_truth_boxes, iou_threshold=0.5, box_format="midpoint", num_classes=20
):
    """
    Calculates Mean Average Precision (mAP) for object detection.

    Args:
        predicted_boxes (List[List[float]]): List of predicted bounding boxes, each specified as
            [image_id, class_prediction, confidence_score, x1, y1, x2, y2]
        ground_truth_boxes (List[List[float]]): List of ground truth bounding boxes, same format as predicted_boxes
        iou_threshold (float): IoU threshold for considering a prediction as correct
        box_format (str): Format of bounding boxes - "midpoint" or "corners"
        num_classes (int): Number of classes in the dataset

    Returns:
        float: mAP value across all classes given a specific IoU threshold
    """

    average_precisions = []

    #for numerical stability
    epsilon = 1e-6

    for class_id in range(num_classes):
        detections = []
        ground_truths = []

        for detection in predicted_boxes:
            if detection[1] == class_id:
                detections.append(detection)

        for true_box in ground_truth_boxes:
            if true_box[1] == class_id:
                ground_truths.append(true_box)

        if len(detections) > 0 and len(ground_truths) > 0:
            # print(f"\nClass {c}:")
            # print(f"Sample detection: {detections[0]}")
            # print(f"Sample ground truth: {ground_truths[0]}")

            # Debug IoU calculation
            sample_iou = calculate_iou(
                torch.tensor(detections[0][3:]),
                torch.tensor(ground_truths[0][3:]),
                box_format=box_format
            )

        if not detections or not ground_truths:
            continue

        # Counting the number of ground truth boxes for each image
        gt_counts = Counter([gt[0] for gt in ground_truths])

        for image_id, count in gt_counts.items():
            gt_counts[image_id] = torch.zeros(count)

        # Sorting detections by confidence score (descending)
        detections.sort(key=lambda x: x[2], reverse=True)
        true_positives = torch.zeros((len(detections)))
        false_positives = torch.zeros((len(detections)))
        total_true_bboxes = len(ground_truths)

        # If none exists for this class then we can safely skip
        if total_true_bboxes == 0:
            continue

        for detection_idx, detection in enumerate(detections):

            image_ground_truths = [
                gt for gt in ground_truths if gt[0] == detection[0]
            ]

            best_iou = 0
            best_gt_idx = None

            for idx, gt in enumerate(image_ground_truths):
                iou = calculate_iou(
                    torch.tensor(detection[3:]),
                    torch.tensor(gt[3:]),
                    box_format=box_format,
                )

                if iou > best_iou:
                    best_iou = iou
                    best_gt_idx = idx

            if best_iou > iou_threshold:
                # only detect ground truth detection once
                if gt_counts[detection[0]][best_gt_idx] == 0:
                    # true positive and add this bounding box to seen
                    true_positives[detection_idx] = 1
                    gt_counts[detection[0]][best_gt_idx] = 1
                else:
                    false_positives[detection_idx] = 1

            # if IOU is lower then the detection is a false positive
            else:
                false_positives[detection_idx] = 1

        # Calculating cumulative sums
        TP_cumsum = torch.cumsum(true_positives, dim=0)
        FP_cumsum = torch.cumsum(false_positives, dim=0)

        recalls = TP_cumsum / (total_true_bboxes + epsilon)
        precisions = torch.divide(TP_cumsum, (TP_cumsum + FP_cumsum + epsilon))

        # Appending 0 recall and 1 precision for AUC calculation
        precisions = torch.cat((torch.tensor([1]), precisions))
        recalls = torch.cat((torch.tensor([0]), recalls))

        # Calculating average precision using trapezoidal rule
        average_precisions.append(torch.trapz(precisions, recalls))

    if not average_precisions:
        print("Warning: No valid predictions were made for any class.")
        return 0.0  # Return 0 mAP if no valid predictions

    return sum(average_precisions) / len(average_precisions)


def plot_image(image, bounding_boxes, class_labels):
    # Plots predicted bounding boxes and their labels on the given image.
    image = np.array(image)
    height, width, _ = image.shape

    # Create figure and axes
    fig, ax = plt.subplots(1)

    # Display the image
    ax.imshow(image)

    for box, label in zip(bounding_boxes, class_labels):
        box = box[2:]
        assert len(box) == 4, "Got more values than in x, y, w, h, in a box!"

        # Extracting box coordinates
        x_center, y_center, box_width, box_height = box
        x_min = (x_center - box_width / 2) * width
        y_min = (y_center - box_height / 2) * height

        # Creating rectangle patch
        rect = patches.Rectangle(
            (x_min, y_min),
            box_width * width,
            box_height * height,
            linewidth=1,
            edgecolor="r",
            facecolor="none",
        )
        # Adding the rectangle to the plot
        ax.add_patch(rect)

        # Adding label above the box
        ax.text(x_min, y_min, label, color='red')

    plt.show()


def extract_bounding_boxes(
    loader,
    model,
    iou_threshold,
    threshold,
    pred_format="cells",
    box_format="midpoint",
    device="cpu",
):
    """
    Extracts predicted and true bounding boxes from a data loader using a given model.

    Args:
        data_loader: DataLoader providing batches of images and labels
        model: Trained model used for making predictions
        iou_threshold (float): IoU threshold for non-max suppression
        confidence_threshold (float): Confidence threshold to filter predictions
        prediction_format (str): Format of predictions - "cells" or other
        box_format (str): Format of bounding boxes - "midpoint" or "corners"
        device (str): Device to run the model on ("cpu" or "cuda")

    Returns:
        Tuple[List[List[float]], List[List[float]]]: Lists of predicted and true bounding boxes
    """
    all_pred_boxes = []
    all_true_boxes = []

    # make sure model is in eval before get bboxes
    model.eval()
    train_idx = 0

    for batch_idx, (x, labels) in enumerate(loader):
        x = x.to(device)
        labels = labels.to(device)

        with torch.no_grad():
            predictions = model(x)

        batch_size = x.shape[0]
        true_bboxes = convert_yolo_output_to_boxes(labels)
        bboxes = convert_yolo_output_to_boxes(predictions)

        for idx in range(batch_size):
            nms_boxes = non_max_suppression(
                bboxes[idx],
                iou_threshold=iou_threshold,
                confidence_threshold=threshold,
                box_format=box_format,
            )


            # if batch_idx == 0 and idx == 0:
            #     print("\nPrediction confidences before NMS:")
            #     for box in bboxes[idx]:
            #         print(f"Class: {box[0]}, Confidence: {box[1]:.4f}")

            #     print("\nPredictions after NMS:")
            #     for box in nms_boxes:
            #         print(f"Class: {box[0]}, Confidence: {box[1]:.4f}")

            for nms_box in nms_boxes:
                all_pred_boxes.append([train_idx] + nms_box)

            for box in true_bboxes[idx]:
                # many will get converted to 0 pred
                if box[1] > threshold:
                    all_true_boxes.append([train_idx] + box)

            train_idx += 1

    model.train()
    return all_pred_boxes, all_true_boxes



def convert_yolo_predictions(predictions, S=7):
    """
    Converts YOLO predictions from cell-relative coordinates to image-relative coordinates.

    Args:
        predictions (torch.Tensor): Raw predictions from YOLO model
        grid_size (int): Size of the grid used in YOLO (default: 7)

    Returns:
        torch.Tensor: Converted predictions in image-relative coordinates
    """

    predictions = predictions.to("cpu")
    batch_size = predictions.shape[0]
    predictions = predictions.reshape(batch_size, 7, 7, 30)

    # Extracting bounding box predictions
    box_1 = predictions[..., 21:25]
    box_2 = predictions[..., 26:30]

    # Determining which box has higher confidence score
    scores = torch.cat(
        (predictions[..., 20].unsqueeze(0), predictions[..., 25].unsqueeze(0)), dim=0
    )
    best_box = scores.argmax(0).unsqueeze(-1)
    best_boxes = box_1 * (1 - best_box) + best_box * box_2

    # Creating grid cell indices
    cell_indices = torch.arange(7).repeat(batch_size, 7, 1).unsqueeze(-1)

    # Converting x and y coordinates
    x_coord = 1 / S * (best_boxes[..., :1] + cell_indices)
    y_coord = 1 / S * (best_boxes[..., 1:2] + cell_indices.permute(0, 2, 1, 3))

    # Converting width and height
    width_height = 1 / S * best_boxes[..., 2:4]

    # Combining converted coordinates
    converted_boxes = torch.cat((x_coord, y_coord, width_height), dim=-1)

     # Getting predicted class and best confidence score
    predicted_class = predictions[..., :20].argmax(-1).unsqueeze(-1)
    best_confidence = torch.max(predictions[..., 20], predictions[..., 25]).unsqueeze(
        -1
    )

    # Combining all predictions
    converted_predictions = torch.cat(
        (predicted_class, best_confidence, converted_boxes), dim=-1
    )

    return converted_predictions

def convert_yolo_output_to_boxes(yolo_output, S=7):
    """
    Converts YOLO output from cell-based format to a list of bounding boxes for each image in the batch.

    Args:
        yolo_output (torch.Tensor): Raw output from YOLO model
        grid_size (int): Size of the grid used in YOLO (default: 7)

    Returns:
        List[List[List[float]]]: List of bounding boxes for each image in the batch
    """
    # Converting cell-based predictions to image-based predictions
    converted_predictions = convert_yolo_predictions(yolo_output).reshape(yolo_output.shape[0], S * S, -1)

    # Converting class predictions to long integers
    converted_predictions[..., 0] = converted_predictions[..., 0].long()
    all_bounding_boxes = []

    for image_index in range(yolo_output.shape[0]):
        image_bounding_boxes = []

        for cell_index in range(S * S):
            # Extracting and converting each prediction to a list of floats
            box = [x.item() for x in converted_predictions[image_index, cell_index, :]]
            image_bounding_boxes.append(box)
        all_bounding_boxes.append(image_bounding_boxes)

    return all_bounding_boxes

def save_checkpoint(state, filename="CS512_YOLO.pth.tar"):
    print("=> Saving checkpoint")
    torch.save(state, filename)


def load_checkpoint(checkpoint, model, optimizer):
    print("=> Loading checkpoint")
    model.load_state_dict(checkpoint["state_dict"])
    optimizer.load_state_dict(checkpoint["optimizer"])

# %%
# ----------------------------------   YOLO LOSS Function   -----------------------------------------------------------------

import torch
import torch.nn as nn


class YoloLoss(nn.Module):
    """
    Loss calculation for our YOLO Model
    """

    def __init__(self, S=7, B=2, C=20):
        super(YoloLoss, self).__init__()
        self.mse = nn.MSELoss(reduction="sum")

        """
        S is split size of image - 7 in original paper,
        B is number of boxes - 2 in original paper,
        C is number of classes - 20 ,
        """
        self.S = S
        self.B = B
        self.C = C

         # Loss weights as given in the paper
        self.lambda_noobj = 0.5  # Weight for no-object confidence loss
        self.lambda_coord = 5    # Weight for bounding box coordinate loss

    def forward(self, predictions, target):
        # predictions are shaped (BATCH_SIZE, S*S(C+B*5)
        predictions = predictions.reshape(-1, self.S, self.S, self.C + self.B * 5)

        # Calculating IoU for the two predicted bounding boxes with target bounding boxes
        iou_b1 = calculate_iou(predictions[..., 21:25], target[..., 21:25])
        iou_b2 = calculate_iou(predictions[..., 26:30], target[..., 21:25])
        ious = torch.cat([iou_b1.unsqueeze(0), iou_b2.unsqueeze(0)], dim=0)

        # Getting the box with highest IoU
        iou_maxes, bestbox = torch.max(ious, dim=0)
        exists_box = target[..., 20].unsqueeze(3)

        # === ===========  Bounding Box Coordinate Loss ==================

        box_predictions = exists_box * (
            (
                bestbox * predictions[..., 26:30]
                + (1 - bestbox) * predictions[..., 21:25]
            )
        )

        box_targets = exists_box * target[..., 21:25]

        # Applying sqrt to width and height
        box_predictions[..., 2:4] = torch.sign(box_predictions[..., 2:4]) * torch.sqrt(
            torch.abs(box_predictions[..., 2:4] + 1e-6)
        )
        box_targets[..., 2:4] = torch.sqrt(box_targets[..., 2:4])

        box_loss = self.mse(
            torch.flatten(box_predictions, end_dim=-2),
            torch.flatten(box_targets, end_dim=-2),
        )

        # ==============================   Object Confidence Loss   ==============
        pred_box = (
            bestbox * predictions[..., 25:26] + (1 - bestbox) * predictions[..., 20:21]
        )

        object_loss = self.mse(
            torch.flatten(exists_box * pred_box),
            torch.flatten(exists_box * target[..., 20:21]),
        )

          # ==============================  No Object Confidence Loss   ==============

        no_object_loss = self.mse(
            torch.flatten((1 - exists_box) * predictions[..., 20:21], start_dim=1),
            torch.flatten((1 - exists_box) * target[..., 20:21], start_dim=1),
        )

        no_object_loss += self.mse(
            torch.flatten((1 - exists_box) * predictions[..., 25:26], start_dim=1),
            torch.flatten((1 - exists_box) * target[..., 20:21], start_dim=1)
        )


         # =============================   Class Prediction Loss      ========================================

        class_loss = self.mse(
            torch.flatten(exists_box * predictions[..., :20], end_dim=-2,),
            torch.flatten(exists_box * target[..., :20], end_dim=-2,),
        )

        # combining all losses
        total_loss = (
            self.lambda_coord * box_loss  # first two losses component in total loss as given in paper
            + object_loss  # 3rd two losses component in total loss as given in paper
            + self.lambda_noobj * no_object_loss  # 4th two losses component in total loss as given in paper
            + class_loss  # 5th two losses component in total loss as given in paper
        )

        return total_loss

# %%
# -------------------------------------   Loading and processing the Pascal VOC dataset.  ---------------------------------------------------

import torch
import os
import pandas as pd
from PIL import Image

class VOCDataset(torch.utils.data.Dataset):
    def __init__(
        self,
        csv_file: str,
        image_dir: str,
        label_dir: str,
        grid_size: int = 7,
        num_boxes: int = 2,
        num_classes: int = 20,
        transform = None,
    ):
        self.annotations = pd.read_csv(csv_file)
        self.image_dir = image_dir
        self.label_dir = label_dir
        self.transform = transform
        self.grid_size = grid_size
        self.num_boxes = num_boxes
        self.num_classes = num_classes

    def __len__(self):
        return len(self.annotations)

    def __getitem__(self, index: int):
        # Loading image and bounding box data
        image, bounding_boxes = self._load_image_and_boxes(index)

        # Applying transformations if specified
        if self.transform:
            image, bounding_boxes = self.transform(image, bounding_boxes)

        # Converting bounding boxes to grid cell format
        label_matrix = self._convert_to_grid_format(bounding_boxes)

        return image, label_matrix

    def _load_image_and_boxes(self, index):
        # Loading bounding box data
        label_path = os.path.join(self.label_dir, self.annotations.iloc[index, 1])
        bounding_boxes = []
        with open(label_path) as f:
            for label in f.readlines():
                class_label, x, y, width, height = [
                    float(x) if float(x) != int(float(x)) else int(x)
                    for x in label.replace("\n", "").split()
                ]
                bounding_boxes.append([class_label, x, y, width, height])

        # Loading the image
        img_path = os.path.join(self.image_dir, self.annotations.iloc[index, 0])
        image = Image.open(img_path)

        return image, torch.tensor(bounding_boxes)

    def _convert_to_grid_format(self, bounding_boxes):
        label_matrix = torch.zeros((self.grid_size, self.grid_size, self.num_classes + 5 * self.num_boxes))

        for box in bounding_boxes:
            class_label, x, y, width, height = box.tolist()
            class_label = int(class_label)

            # Calculating grid cell indices
            i, j = int(self.grid_size * y), int(self.grid_size * x)

            # Calculating box coordinates relative to the cell
            x_cell, y_cell = self.grid_size * x - j, self.grid_size * y - i
            width_cell, height_cell = width * self.grid_size, height * self.grid_size

            # Assigning values to the label matrix if no object is already present in the cell
            if label_matrix[i, j, 20] == 0:
                label_matrix[i, j, 20] = 1  # Object presence flag
                label_matrix[i, j, 21:25] = torch.tensor([x_cell, y_cell, width_cell, height_cell])
                label_matrix[i, j, class_label] = 1  # One-hot encoding for class label

        return label_matrix

# %%
#######################  This code is taken from Perplexity AI ###########################
# Method 1: Using Google Drive Mount
from google.colab import drive
drive.mount('/content/drive')

# Create a directory for the dataset
# !mkdir -p /content/pascal_voc

# Assuming PASCAL_VOC.zip is in your main Drive folder
# !cp '/content/drive/My Drive/PASCAL_VOC.zip' /content/pascal_voc/
# !cd /content/pascal_voc && unzip PASCAL_VOC.zip

# Method 2: Using gdown (if you have a shareable link)
# First, get the shareable link from Google Drive:
# 1. Right-click on PASCAL_VOC.zip
# 2. Click "Share" -> "Anyone with the link"
# 3. Copy the link

# !pip install gdown

# Replace FILE_ID with your actual file ID from the shareable link
# Example: if link is https://drive.google.com/file/d/1234xyz/view
# then FILE_ID is 1234xyz
# !gdown --id FILE_ID -O /content/pascal_voc/PASCAL_VOC.zip
# !cd /content/pascal_voc && unzip PASCAL_VOC.zip

# Verify the extraction
# !ls /content/pascal_voc

# Expected structure:
# /content/pascal_voc/
#   ├── Annotations/
#   ├── ImageSets/
#   │   └── Main/
#   └── JPEGImages/

# Clean up the zip file to save space
# !rm /content/pascal_voc/PASCAL_VOC.zip

#######################  This code is taken from Perplexity AI ###########################
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: labels/2009_004347.txt
#   inflating: labels/2009_004350.txt
#   inflating: labels/2009_004351.txt
#   inflating: labels/2009_004357.txt
#   inflating: labels/2009_004358.txt
#   inflating: labels/2009_004359.txt
#   inflating: labels/2009_004361.txt
#   inflating: labels/2009_004364.txt
#   inflating: labels/2009_004366.txt
#   inflating: labels/2009_004368.txt
#   inflating: labels/2009_004369.txt
#   inflating: labels/2009_004370.txt
#   inflating: labels/2009_004371.txt
#   inflating: labels/2009_004374.txt
#   inflating: labels/2009_004375.txt
#   inflating: labels/2009_004377.txt
#   inflating: labels/2009_004382.txt
#   inflating: labels/2009_004383.txt
#   inflating: labels/2009_004390.txt
#   inflating: labels/2009_004392.txt
#   inflating: labels/2009_004394.txt
#   inflating: labels/2009_004397.txt
#   inflating: labels/2009_004399.txt
#   inflating: labels/2009_004402.txt
#   inflating: labels/2009_004403.txt
#   inflating: labels/2009_004404.txt
#   inflating: labels/2009_004406.txt
#   inflating: labels/2009_004409.txt
#   inflating: labels/2009_004410.txt
#   inflating: labels/2009_004411.txt
#   inflating: labels/2009_004414.txt
#   inflating: labels/2009_004417.txt
#   inflating: labels/2009_004419.txt
#   inflating: labels/2009_004424.txt
#   inflating: labels/2009_004425.txt
#   inflating: labels/2009_004426.txt
#   inflating: labels/2009_004429.txt
#   inflating: labels/2009_004432.txt
#   inflating: labels/2009_004434.txt
#   inflating: labels/2009_004435.txt
#   inflating: labels/2009_004436.txt
#   inflating: labels/2009_004438.txt
#   inflating: labels/2009_004440.txt
#   inflating: labels/2009_004442.txt
#   inflating: labels/2009_004444.txt
#   inflating: labels/2009_004445.txt
#   inflating: labels/2009_004446.txt
#   inflating: labels/2009_004448.txt
#   inflating: labels/2009_004449.txt
#   inflating: labels/2009_004451.txt
#   inflating: labels/2009_004452.txt
#   inflating: labels/2009_004453.txt
#   inflating: labels/2009_004454.txt
#   inflating: labels/2009_004455.txt
#   inflating: labels/2009_004456.txt
#   inflating: labels/2009_004457.txt
#   inflating: labels/2009_004464.txt
#   inflating: labels/2009_004465.txt
#   inflating: labels/2009_004468.txt
#   inflating: labels/2009_004471.txt
#   inflating: labels/2009_004475.txt
#   inflating: labels/2009_004477.txt
#   inflating: labels/2009_004478.txt
#   inflating: labels/2009_004479.txt
#   inflating: labels/2009_004483.txt
#   inflating: labels/2009_004486.txt
#   inflating: labels/2009_004492.txt
#   inflating: labels/2009_004494.txt
#   inflating: labels/2009_004496.txt
#   inflating: labels/2009_004497.txt
#   inflating: labels/2009_004499.txt
#   inflating: labels/2009_004501.txt
#   inflating: labels/2009_004502.txt
#   inflating: labels/2009_004503.txt
#   inflating: labels/2009_004504.txt
#   inflating: labels/2009_004507.txt
#   inflating: labels/2009_004508.txt
#   inflating: labels/2009_004509.txt
#   inflating: labels/2009_004511.txt
#   inflating: labels/2009_004513.txt
#   inflating: labels/2009_004514.txt
#   inflating: labels/2009_004518.txt
#   inflating: labels/2009_004519.txt
#   inflating: labels/2009_004524.txt
#   inflating: labels/2009_004525.txt
#   inflating: labels/2009_004527.txt
#   inflating: labels/2009_004529.txt
#   inflating: labels/2009_004530.txt
#   inflating: labels/2009_004532.txt
#   inflating: labels/2009_004535.txt
#   inflating: labels/2009_004536.txt
#   inflating: labels/2009_004537.txt
#   inflating: labels/2009_004539.txt
#   inflating: labels/2009_004540.txt
#   inflating: labels/2009_004542.txt
#   inflating: labels/2009_004543.txt
#   inflating: labels/2009_004545.txt
#   inflating: labels/2009_004547.txt
#   inflating: labels/2009_004548.txt
#   inflating: labels/2009_004551.txt
#   inflating: labels/2009_004552.txt
#   inflating: labels/2009_004554.txt
#   inflating: labels/2009_004556.txt
#   inflating: labels/2009_004557.txt
#   inflating: labels/2009_004559.txt
#   inflating: labels/2009_004560.txt
#   inflating: labels/2009_004561.txt
#   inflating: labels/2009_004562.txt
#   inflating: labels/2009_004565.txt
#   inflating: labels/2009_004567.txt
#   inflating: labels/2009_004568.txt
#   inflating: labels/2009_004570.txt
#   inflating: labels/2009_004571.txt
#   inflating: labels/2009_004572.txt
#   inflating: labels/2009_004579.txt
#   inflating: labels/2009_004580.txt
#   inflating: labels/2009_004581.txt
#   inflating: labels/2009_004582.txt
#   inflating: labels/2009_004587.txt
#   inflating: labels/2009_004588.txt
#   inflating: labels/2009_004590.txt
#   inflating: labels/2009_004592.txt
#   inflating: labels/2009_004593.txt
#   inflating: labels/2009_004594.txt
#   inflating: labels/2009_004598.txt
#   inflating: labels/2009_004601.txt
#   inflating: labels/2009_004606.txt
#   inflating: labels/2009_004607.txt
#   inflating: labels/2009_004614.txt
#   inflating: labels/2009_004616.txt
#   inflating: labels/2009_004619.txt
#   inflating: labels/2009_004620.txt
#   inflating: labels/2009_004623.txt
#   inflating: labels/2009_004624.txt
#   inflating: labels/2009_004625.txt
#   inflating: labels/2009_004626.txt
#   inflating: labels/2009_004628.txt
#   inflating: labels/2009_004629.txt
#   inflating: labels/2009_004630.txt
#   inflating: labels/2009_004631.txt
#   inflating: labels/2009_004634.txt
#   inflating: labels/2009_004635.txt
#   inflating: labels/2009_004639.txt
#   inflating: labels/2009_004642.txt
#   inflating: labels/2009_004643.txt
#   inflating: labels/2009_004645.txt
#   inflating: labels/2009_004647.txt
#   inflating: labels/2009_004648.txt
#   inflating: labels/2009_004651.txt
#   inflating: labels/2009_004652.txt
#   inflating: labels/2009_004653.txt
#   inflating: labels/2009_004655.txt
#   inflating: labels/2009_004656.txt
#   inflating: labels/2009_004661.txt
#   inflating: labels/2009_004662.txt
#   inflating: labels/2009_004664.txt
#   inflating: labels/2009_004667.txt
#   inflating: labels/2009_004669.txt
#   inflating: labels/2009_004670.txt
#   inflating: labels/2009_004671.txt
#   inflating: labels/2009_004674.txt
#   inflating: labels/2009_004677.txt
#   inflating: labels/2009_004679.txt
#   inflating: labels/2009_004681.txt
#   inflating: labels/2009_004683.txt
#   inflating: labels/2009_004684.txt
#   inflating: labels/2009_004686.txt
#   inflating: labels/2009_004687.txt
#   inflating: labels/2009_004688.txt
#   inflating: labels/2009_004694.txt
#   inflating: labels/2009_004697.txt
#   inflating: labels/2009_004701.txt
#   inflating: labels/2009_004705.txt
#   inflating: labels/2009_004706.txt
#   inflating: labels/2009_004708.txt
#   inflating: labels/2009_004709.txt
#   inflating: labels/2009_004710.txt
#   inflating: labels/2009_004713.txt
#   inflating: labels/2009_004716.txt
#   inflating: labels/2009_004718.txt
#   inflating: labels/2009_004719.txt
#   inflating: labels/2009_004720.txt
#   inflating: labels/2009_004721.txt
#   inflating: labels/2009_004723.txt
#   inflating: labels/2009_004728.txt
#   inflating: labels/2009_004730.txt
#   inflating: labels/2009_004731.txt
#   inflating: labels/2009_004732.txt
#   inflating: labels/2009_004734.txt
#   inflating: labels/2009_004737.txt
#   inflating: labels/2009_004738.txt
#   inflating: labels/2009_004744.txt
#   inflating: labels/2009_004745.txt
#   inflating: labels/2009_004746.txt
#   inflating: labels/2009_004748.txt
#   inflating: labels/2009_004749.txt
#   inflating: labels/2009_004754.txt
#   inflating: labels/2009_004756.txt
#   inflating: labels/2009_004758.txt
#   inflating: labels/2009_004759.txt
#   inflating: labels/2009_004760.txt
#   inflating: labels/2009_004761.txt
#   inflating: labels/2009_004763.txt
#   inflating: labels/2009_004764.txt
#   inflating: labels/2009_004765.txt
#   inflating: labels/2009_004766.txt
#   inflating: labels/2009_004768.txt
#   inflating: labels/2009_004769.txt
#   inflating: labels/2009_004771.txt
#   inflating: labels/2009_004772.txt
#   inflating: labels/2009_004779.txt
#   inflating: labels/2009_004780.txt
#   inflating: labels/2009_004781.txt
#   inflating: labels/2009_004782.txt
#   inflating: labels/2009_004784.txt
#   inflating: labels/2009_004786.txt
#   inflating: labels/2009_004787.txt
#   inflating: labels/2009_004789.txt
#   inflating: labels/2009_004790.txt
#   inflating: labels/2009_004794.txt
#   inflating: labels/2009_004796.txt
#   inflating: labels/2009_004797.txt
#   inflating: labels/2009_004798.txt
#   inflating: labels/2009_004799.txt
#   inflating: labels/2009_004801.txt
#   inflating: labels/2009_004804.txt
#   inflating: labels/2009_004805.txt
#   inflating: labels/2009_004806.txt
#   inflating: labels/2009_004812.txt
#   inflating: labels/2009_004813.txt
#   inflating: labels/2009_004815.txt
#   inflating: labels/2009_004817.txt
#   inflating: labels/2009_004820.txt
#   inflating: labels/2009_004822.txt
#   inflating: labels/2009_004823.txt
#   inflating: labels/2009_004824.txt
#   inflating: labels/2009_004828.txt
#   inflating: labels/2009_004829.txt
#   inflating: labels/2009_004830.txt
#   inflating: labels/2009_004831.txt
#   inflating: labels/2009_004834.txt
#   inflating: labels/2009_004836.txt
#   inflating: labels/2009_004839.txt
#   inflating: labels/2009_004841.txt
#   inflating: labels/2009_004845.txt
#   inflating: labels/2009_004846.txt
#   inflating: labels/2009_004847.txt
#   inflating: labels/2009_004848.txt
#   inflating: labels/2009_004849.txt
#   inflating: labels/2009_004855.txt
#   inflating: labels/2009_004856.txt
#   inflating: labels/2009_004857.txt
#   inflating: labels/2009_004858.txt
#   inflating: labels/2009_004859.txt
#   inflating: labels/2009_004865.txt
#   inflating: labels/2009_004867.txt
#   inflating: labels/2009_004868.txt
#   inflating: labels/2009_004869.txt
#   inflating: labels/2009_004871.txt
#   inflating: labels/2009_004872.txt
#   inflating: labels/2009_004874.txt
#   inflating: labels/2009_004876.txt
#   inflating: labels/2009_004877.txt
#   inflating: labels/2009_004880.txt
#   inflating: labels/2009_004882.txt
#   inflating: labels/2009_004885.txt
#   inflating: labels/2009_004886.txt
#   inflating: labels/2009_004887.txt
#   inflating: labels/2009_004888.txt
#   inflating: labels/2009_004889.txt
#   inflating: labels/2009_004890.txt
#   inflating: labels/2009_004895.txt
#   inflating: labels/2009_004897.txt
#   inflating: labels/2009_004898.txt
#   inflating: labels/2009_004899.txt
#   inflating: labels/2009_004901.txt
#   inflating: labels/2009_004902.txt
#   inflating: labels/2009_004903.txt
#   inflating: labels/2009_004904.txt
#   inflating: labels/2009_004905.txt
#   inflating: labels/2009_004907.txt
#   inflating: labels/2009_004913.txt
#   inflating: labels/2009_004914.txt
#   inflating: labels/2009_004917.txt
#   inflating: labels/2009_004919.txt
#   inflating: labels/2009_004921.txt
#   inflating: labels/2009_004922.txt
#   inflating: labels/2009_004926.txt
#   inflating: labels/2009_004929.txt
#   inflating: labels/2009_004930.txt
#   inflating: labels/2009_004933.txt
#   inflating: labels/2009_004934.txt
#   inflating: labels/2009_004939.txt
#   inflating: labels/2009_004940.txt
#   inflating: labels/2009_004942.txt
#   inflating: labels/2009_004943.txt
#   inflating: labels/2009_004944.txt
#   inflating: labels/2009_004945.txt
#   inflating: labels/2009_004946.txt
#   inflating: labels/2009_004947.txt
#   inflating: labels/2009_004953.txt
#   inflating: labels/2009_004956.txt
#   inflating: labels/2009_004958.txt
#   inflating: labels/2009_004959.txt
#   inflating: labels/2009_004961.txt
#   inflating: labels/2009_004962.txt
#   inflating: labels/2009_004965.txt
#   inflating: labels/2009_004969.txt
#   inflating: labels/2009_004971.txt
#   inflating: labels/2009_004972.txt
#   inflating: labels/2009_004974.txt
#   inflating: labels/2009_004975.txt
#   inflating: labels/2009_004977.txt
#   inflating: labels/2009_004979.txt
#   inflating: labels/2009_004980.txt
#   inflating: labels/2009_004982.txt
#   inflating: labels/2009_004983.txt
#   inflating: labels/2009_004984.txt
#   inflating: labels/2009_004986.txt
#   inflating: labels/2009_004987.txt
#   inflating: labels/2009_004988.txt
#   inflating: labels/2009_004990.txt
#   inflating: labels/2009_004993.txt
#   inflating: labels/2009_004994.txt
#   inflating: labels/2009_004996.txt
#   inflating: labels/2009_004999.txt
#   inflating: labels/2009_005000.txt
#   inflating: labels/2009_005001.txt
#   inflating: labels/2009_005005.txt
#   inflating: labels/2009_005006.txt
#   inflating: labels/2009_005008.txt
#   inflating: labels/2009_005015.txt
#   inflating: labels/2009_005016.txt
#   inflating: labels/2009_005019.txt
#   inflating: labels/2009_005024.txt
#   inflating: labels/2009_005025.txt
#   inflating: labels/2009_005030.txt
#   inflating: labels/2009_005031.txt
#   inflating: labels/2009_005033.txt
#   inflating: labels/2009_005035.txt
#   inflating: labels/2009_005036.txt
#   inflating: labels/2009_005037.txt
#   inflating: labels/2009_005038.txt
#   inflating: labels/2009_005040.txt
#   inflating: labels/2009_005042.txt
#   inflating: labels/2009_005044.txt
#   inflating: labels/2009_005045.txt
#   inflating: labels/2009_005051.txt
#   inflating: labels/2009_005055.txt
#   inflating: labels/2009_005056.txt
#   inflating: labels/2009_005057.txt
#   inflating: labels/2009_005060.txt
#   inflating: labels/2009_005061.txt
#   inflating: labels/2009_005062.txt
#   inflating: labels/2009_005064.txt
#   inflating: labels/2009_005068.txt
#   inflating: labels/2009_005069.txt
#   inflating: labels/2009_005070.txt
#   inflating: labels/2009_005073.txt
#   inflating: labels/2009_005075.txt
#   inflating: labels/2009_005076.txt
#   inflating: labels/2009_005078.txt
#   inflating: labels/2009_005079.txt
#   inflating: labels/2009_005080.txt
#   inflating: labels/2009_005081.txt
#   inflating: labels/2009_005082.txt
#   inflating: labels/2009_005083.txt
#   inflating: labels/2009_005084.txt
#   inflating: labels/2009_005085.txt
#   inflating: labels/2009_005086.txt
#   inflating: labels/2009_005087.txt
#   inflating: labels/2009_005089.txt
#   inflating: labels/2009_005094.txt
#   inflating: labels/2009_005095.txt
#   inflating: labels/2009_005098.txt
#   inflating: labels/2009_005102.txt
#   inflating: labels/2009_005103.txt
#   inflating: labels/2009_005104.txt
#   inflating: labels/2009_005107.txt
#   inflating: labels/2009_005111.txt
#   inflating: labels/2009_005114.txt
#   inflating: labels/2009_005118.txt
#   inflating: labels/2009_005119.txt
#   inflating: labels/2009_005120.txt
#   inflating: labels/2009_005126.txt
#   inflating: labels/2009_005127.txt
#   inflating: labels/2009_005128.txt
#   inflating: labels/2009_005129.txt
#   inflating: labels/2009_005130.txt
#   inflating: labels/2009_005131.txt
#   inflating: labels/2009_005133.txt
#   inflating: labels/2009_005137.txt
#   inflating: labels/2009_005140.txt
#   inflating: labels/2009_005141.txt
#   inflating: labels/2009_005142.txt
#   inflating: labels/2009_005144.txt
#   inflating: labels/2009_005145.txt
#   inflating: labels/2009_005147.txt
#   inflating: labels/2009_005148.txt
#   inflating: labels/2009_005149.txt
#   inflating: labels/2009_005150.txt
#   inflating: labels/2009_005152.txt
#   inflating: labels/2009_005153.txt
#   inflating: labels/2009_005154.txt
#   inflating: labels/2009_005155.txt
#   inflating: labels/2009_005156.txt
#   inflating: labels/2009_005158.txt
#   inflating: labels/2009_005160.txt
#   inflating: labels/2009_005161.txt
#   inflating: labels/2009_005162.txt
#   inflating: labels/2009_005163.txt
#   inflating: labels/2009_005165.txt
#   inflating: labels/2009_005168.txt
#   inflating: labels/2009_005170.txt
#   inflating: labels/2009_005171.txt
#   inflating: labels/2009_005172.txt
#   inflating: labels/2009_005177.txt
#   inflating: labels/2009_005178.txt
#   inflating: labels/2009_005181.txt
#   inflating: labels/2009_005183.txt
#   inflating: labels/2009_005185.txt
#   inflating: labels/2009_005189.txt
#   inflating: labels/2009_005190.txt
#   inflating: labels/2009_005191.txt
#   inflating: labels/2009_005193.txt
#   inflating: labels/2009_005194.txt
#   inflating: labels/2009_005198.txt
#   inflating: labels/2009_005201.txt
#   inflating: labels/2009_005202.txt
#   inflating: labels/2009_005203.txt
#   inflating: labels/2009_005204.txt
#   inflating: labels/2009_005205.txt
#   inflating: labels/2009_005210.txt
#   inflating: labels/2009_005211.txt
#   inflating: labels/2009_005215.txt
#   inflating: labels/2009_005216.txt
#   inflating: labels/2009_005217.txt
#   inflating: labels/2009_005218.txt
#   inflating: labels/2009_005219.txt
#   inflating: labels/2009_005220.txt
#   inflating: labels/2009_005221.txt
#   inflating: labels/2009_005222.txt
#   inflating: labels/2009_005225.txt
#   inflating: labels/2009_005229.txt
#   inflating: labels/2009_005231.txt
#   inflating: labels/2009_005232.txt
#   inflating: labels/2009_005234.txt
#   inflating: labels/2009_005236.txt
#   inflating: labels/2009_005239.txt
#   inflating: labels/2009_005240.txt
#   inflating: labels/2009_005242.txt
#   inflating: labels/2009_005246.txt
#   inflating: labels/2009_005247.txt
#   inflating: labels/2009_005251.txt
#   inflating: labels/2009_005256.txt
#   inflating: labels/2009_005257.txt
#   inflating: labels/2009_005260.txt
#   inflating: labels/2009_005262.txt
#   inflating: labels/2009_005263.txt
#   inflating: labels/2009_005265.txt
#   inflating: labels/2009_005267.txt
#   inflating: labels/2009_005268.txt
#   inflating: labels/2009_005269.txt
#   inflating: labels/2009_005272.txt
#   inflating: labels/2009_005278.txt
#   inflating: labels/2009_005279.txt
#   inflating: labels/2009_005282.txt
#   inflating: labels/2009_005286.txt
#   inflating: labels/2009_005287.txt
#   inflating: labels/2009_005288.txt
#   inflating: labels/2009_005292.txt
#   inflating: labels/2009_005293.txt
#   inflating: labels/2009_005294.txt
#   inflating: labels/2009_005297.txt
#   inflating: labels/2009_005299.txt
#   inflating: labels/2009_005300.txt
#   inflating: labels/2009_005302.txt
#   inflating: labels/2009_005303.txt
#   inflating: labels/2009_005307.txt
#   inflating: labels/2009_005308.txt
#   inflating: labels/2009_005309.txt
#   inflating: labels/2009_005310.txt
#   inflating: labels/2009_005311.txt
#   inflating: labels/2010_000001.txt
#   inflating: labels/2010_000002.txt
#   inflating: labels/2010_000003.txt
#   inflating: labels/2010_000009.txt
#   inflating: labels/2010_000014.txt
#   inflating: labels/2010_000015.txt
#   inflating: labels/2010_000018.txt
#   inflating: labels/2010_000020.txt
#   inflating: labels/2010_000023.txt
#   inflating: labels/2010_000024.txt
#   inflating: labels/2010_000026.txt
#   inflating: labels/2010_000027.txt
#   inflating: labels/2010_000031.txt
#   inflating: labels/2010_000033.txt
#   inflating: labels/2010_000035.txt
#   inflating: labels/2010_000036.txt
#   inflating: labels/2010_000038.txt
#   inflating: labels/2010_000043.txt
#   inflating: labels/2010_000045.txt
#   inflating: labels/2010_000048.txt
#   inflating: labels/2010_000050.txt
#   inflating: labels/2010_000052.txt
#   inflating: labels/2010_000053.txt
#   inflating: labels/2010_000054.txt
#   inflating: labels/2010_000055.txt
#   inflating: labels/2010_000056.txt
#   inflating: labels/2010_000061.txt
#   inflating: labels/2010_000063.txt
#   inflating: labels/2010_000065.txt
#   inflating: labels/2010_000067.txt
#   inflating: labels/2010_000069.txt
#   inflating: labels/2010_000071.txt
#   inflating: labels/2010_000072.txt
#   inflating: labels/2010_000073.txt
#   inflating: labels/2010_000074.txt
#   inflating: labels/2010_000075.txt
#   inflating: labels/2010_000076.txt
#   inflating: labels/2010_000079.txt
#   inflating: labels/2010_000080.txt
#   inflating: labels/2010_000082.txt
#   inflating: labels/2010_000083.txt
#   inflating: labels/2010_000084.txt
#   inflating: labels/2010_000085.txt
#   inflating: labels/2010_000087.txt
#   inflating: labels/2010_000088.txt
#   inflating: labels/2010_000089.txt
#   inflating: labels/2010_000090.txt
#   inflating: labels/2010_000091.txt
#   inflating: labels/2010_000095.txt
#   inflating: labels/2010_000097.txt
#   inflating: labels/2010_000098.txt
#   inflating: labels/2010_000099.txt
#   inflating: labels/2010_000103.txt
#   inflating: labels/2010_000109.txt
#   inflating: labels/2010_000110.txt
#   inflating: labels/2010_000111.txt
#   inflating: labels/2010_000113.txt
#   inflating: labels/2010_000114.txt
#   inflating: labels/2010_000117.txt
#   inflating: labels/2010_000118.txt
#   inflating: labels/2010_000120.txt
#   inflating: labels/2010_000124.txt
#   inflating: labels/2010_000127.txt
#   inflating: labels/2010_000131.txt
#   inflating: labels/2010_000132.txt
#   inflating: labels/2010_000133.txt
#   inflating: labels/2010_000136.txt
#   inflating: labels/2010_000137.txt
#   inflating: labels/2010_000138.txt
#   inflating: labels/2010_000139.txt
#   inflating: labels/2010_000140.txt
#   inflating: labels/2010_000141.txt
#   inflating: labels/2010_000145.txt
#   inflating: labels/2010_000148.txt
#   inflating: labels/2010_000151.txt
#   inflating: labels/2010_000152.txt
#   inflating: labels/2010_000157.txt
#   inflating: labels/2010_000159.txt
#   inflating: labels/2010_000160.txt
#   inflating: labels/2010_000162.txt
#   inflating: labels/2010_000163.txt
#   inflating: labels/2010_000165.txt
#   inflating: labels/2010_000169.txt
#   inflating: labels/2010_000170.txt
#   inflating: labels/2010_000172.txt
#   inflating: labels/2010_000174.txt
#   inflating: labels/2010_000175.txt
#   inflating: labels/2010_000177.txt
#   inflating: labels/2010_000178.txt
#   inflating: labels/2010_000182.txt
#   inflating: labels/2010_000183.txt
#   inflating: labels/2010_000184.txt
#   inflating: labels/2010_000187.txt
#   inflating: labels/2010_000189.txt
#   inflating: labels/2010_000190.txt
#   inflating: labels/2010_000193.txt
#   inflating: labels/2010_000194.txt
#   inflating: labels/2010_000195.txt
#   inflating: labels/2010_000196.txt
#   inflating: labels/2010_000197.txt
#   inflating: labels/2010_000198.txt
#   inflating: labels/2010_000199.txt
#   inflating: labels/2010_000202.txt
#   inflating: labels/2010_000203.txt
#   inflating: labels/2010_000204.txt
#   inflating: labels/2010_000209.txt
#   inflating: labels/2010_000211.txt
#   inflating: labels/2010_000213.txt
#   inflating: labels/2010_000216.txt
#   inflating: labels/2010_000218.txt
#   inflating: labels/2010_000222.txt
#   inflating: labels/2010_000224.txt
#   inflating: labels/2010_000227.txt
#   inflating: labels/2010_000229.txt
#   inflating: labels/2010_000233.txt
#   inflating: labels/2010_000234.txt
#   inflating: labels/2010_000238.txt
#   inflating: labels/2010_000241.txt
#   inflating: labels/2010_000244.txt
#   inflating: labels/2010_000245.txt
#   inflating: labels/2010_000246.txt
#   inflating: labels/2010_000247.txt
#   inflating: labels/2010_000248.txt
#   inflating: labels/2010_000249.txt
#   inflating: labels/2010_000250.txt
#   inflating: labels/2010_000254.txt
#   inflating: labels/2010_000255.txt
#   inflating: labels/2010_000256.txt
#   inflating: labels/2010_000260.txt
#   inflating: labels/2010_000261.txt
#   inflating: labels/2010_000262.txt
#   inflating: labels/2010_000263.txt
#   inflating: labels/2010_000264.txt
#   inflating: labels/2010_000266.txt
#   inflating: labels/2010_000269.txt
#   inflating: labels/2010_000270.txt
#   inflating: labels/2010_000272.txt
#   inflating: labels/2010_000273.txt
#   inflating: labels/2010_000276.txt
#   inflating: labels/2010_000279.txt
#   inflating: labels/2010_000283.txt
#   inflating: labels/2010_000284.txt
#   inflating: labels/2010_000285.txt
#   inflating: labels/2010_000286.txt
#   inflating: labels/2010_000291.txt
#   inflating: labels/2010_000293.txt
#   inflating: labels/2010_000295.txt
#   inflating: labels/2010_000296.txt
#   inflating: labels/2010_000299.txt
#   inflating: labels/2010_000302.txt
#   inflating: labels/2010_000303.txt
#   inflating: labels/2010_000307.txt
#   inflating: labels/2010_000308.txt
#   inflating: labels/2010_000309.txt
#   inflating: labels/2010_000310.txt
#   inflating: labels/2010_000312.txt
#   inflating: labels/2010_000313.txt
#   inflating: labels/2010_000317.txt
#   inflating: labels/2010_000318.txt
#   inflating: labels/2010_000320.txt
#   inflating: labels/2010_000321.txt
#   inflating: labels/2010_000323.txt
#   inflating: labels/2010_000324.txt
#   inflating: labels/2010_000325.txt
#   inflating: labels/2010_000327.txt
#   inflating: labels/2010_000329.txt
#   inflating: labels/2010_000330.txt
#   inflating: labels/2010_000335.txt
#   inflating: labels/2010_000336.txt
#   inflating: labels/2010_000337.txt
#   inflating: labels/2010_000342.txt
#   inflating: labels/2010_000344.txt
#   inflating: labels/2010_000347.txt
#   inflating: labels/2010_000349.txt
#   inflating: labels/2010_000351.txt
#   inflating: labels/2010_000352.txt
#   inflating: labels/2010_000356.txt
#   inflating: labels/2010_000358.txt
#   inflating: labels/2010_000361.txt
#   inflating: labels/2010_000362.txt
#   inflating: labels/2010_000370.txt
#   inflating: labels/2010_000371.txt
#   inflating: labels/2010_000372.txt
#   inflating: labels/2010_000374.txt
#   inflating: labels/2010_000375.txt
#   inflating: labels/2010_000376.txt
#   inflating: labels/2010_000377.txt
#   inflating: labels/2010_000379.txt
#   inflating: labels/2010_000381.txt
#   inflating: labels/2010_000382.txt
#   inflating: labels/2010_000384.txt
#   inflating: labels/2010_000386.txt
#   inflating: labels/2010_000388.txt
#   inflating: labels/2010_000389.txt
#   inflating: labels/2010_000390.txt
#   inflating: labels/2010_000392.txt
#   inflating: labels/2010_000393.txt
#   inflating: labels/2010_000394.txt
#   inflating: labels/2010_000395.txt
#   inflating: labels/2010_000399.txt
#   inflating: labels/2010_000401.txt
#   inflating: labels/2010_000404.txt
#   inflating: labels/2010_000406.txt
#   inflating: labels/2010_000409.txt
#   inflating: labels/2010_000413.txt
#   inflating: labels/2010_000415.txt
#   inflating: labels/2010_000418.txt
#   inflating: labels/2010_000419.txt
#   inflating: labels/2010_000420.txt
#   inflating: labels/2010_000422.txt
#   inflating: labels/2010_000426.txt
#   inflating: labels/2010_000427.txt
#   inflating: labels/2010_000431.txt
#   inflating: labels/2010_000432.txt
#   inflating: labels/2010_000433.txt
#   inflating: labels/2010_000435.txt
#   inflating: labels/2010_000436.txt
#   inflating: labels/2010_000437.txt
#   inflating: labels/2010_000439.txt
#   inflating: labels/2010_000442.txt
#   inflating: labels/2010_000444.txt
#   inflating: labels/2010_000446.txt
#   inflating: labels/2010_000447.txt
#   inflating: labels/2010_000448.txt
#   inflating: labels/2010_000449.txt
#   inflating: labels/2010_000453.txt
#   inflating: labels/2010_000456.txt
#   inflating: labels/2010_000458.txt
#   inflating: labels/2010_000459.txt
#   inflating: labels/2010_000461.txt
#   inflating: labels/2010_000462.txt
#   inflating: labels/2010_000463.txt
#   inflating: labels/2010_000465.txt
#   inflating: labels/2010_000466.txt
#   inflating: labels/2010_000468.txt
#   inflating: labels/2010_000469.txt
#   inflating: labels/2010_000470.txt
#   inflating: labels/2010_000473.txt
#   inflating: labels/2010_000474.txt
#   inflating: labels/2010_000475.txt
#   inflating: labels/2010_000477.txt
#   inflating: labels/2010_000480.txt
#   inflating: labels/2010_000483.txt
#   inflating: labels/2010_000484.txt
#   inflating: labels/2010_000485.txt
#   inflating: labels/2010_000488.txt
#   inflating: labels/2010_000490.txt
#   inflating: labels/2010_000492.txt
#   inflating: labels/2010_000493.txt
#   inflating: labels/2010_000495.txt
#   inflating: labels/2010_000497.txt
#   inflating: labels/2010_000498.txt
#   inflating: labels/2010_000500.txt
#   inflating: labels/2010_000502.txt
#   inflating: labels/2010_000503.txt
#   inflating: labels/2010_000506.txt
#   inflating: labels/2010_000508.txt
#   inflating: labels/2010_000510.txt
#   inflating: labels/2010_000511.txt
#   inflating: labels/2010_000513.txt
#   inflating: labels/2010_000515.txt
#   inflating: labels/2010_000519.txt
#   inflating: labels/2010_000522.txt
#   inflating: labels/2010_000524.txt
#   inflating: labels/2010_000526.txt
#   inflating: labels/2010_000527.txt
#   inflating: labels/2010_000530.txt
#   inflating: labels/2010_000534.txt
#   inflating: labels/2010_000536.txt
#   inflating: labels/2010_000537.txt
#   inflating: labels/2010_000538.txt
#   inflating: labels/2010_000541.txt
#   inflating: labels/2010_000545.txt
#   inflating: labels/2010_000547.txt
#   inflating: labels/2010_000548.txt
#   inflating: labels/2010_000549.txt
#   inflating: labels/2010_000552.txt
#   inflating: labels/2010_000553.txt
#   inflating: labels/2010_000556.txt
#   inflating: labels/2010_000557.txt
#   inflating: labels/2010_000559.txt
#   inflating: labels/2010_000561.txt
#   inflating: labels/2010_000562.txt
#   inflating: labels/2010_000564.txt
#   inflating: labels/2010_000567.txt
#   inflating: labels/2010_000568.txt
#   inflating: labels/2010_000571.txt
#   inflating: labels/2010_000572.txt
#   inflating: labels/2010_000573.txt
#   inflating: labels/2010_000574.txt
#   inflating: labels/2010_000576.txt
#   inflating: labels/2010_000577.txt
#   inflating: labels/2010_000578.txt
#   inflating: labels/2010_000581.txt
#   inflating: labels/2010_000582.txt
#   inflating: labels/2010_000583.txt
#   inflating: labels/2010_000586.txt
#   inflating: labels/2010_000588.txt
#   inflating: labels/2010_000590.txt
#   inflating: labels/2010_000591.txt
#   inflating: labels/2010_000601.txt
#   inflating: labels/2010_000602.txt
#   inflating: labels/2010_000603.txt
#   inflating: labels/2010_000604.txt
#   inflating: labels/2010_000608.txt
#   inflating: labels/2010_000613.txt
#   inflating: labels/2010_000616.txt
#   inflating: labels/2010_000617.txt
#   inflating: labels/2010_000621.txt
#   inflating: labels/2010_000622.txt
#   inflating: labels/2010_000624.txt
#   inflating: labels/2010_000626.txt
#   inflating: labels/2010_000628.txt
#   inflating: labels/2010_000630.txt
#   inflating: labels/2010_000632.txt
#   inflating: labels/2010_000633.txt
#   inflating: labels/2010_000635.txt
#   inflating: labels/2010_000639.txt
#   inflating: labels/2010_000641.txt
#   inflating: labels/2010_000644.txt
#   inflating: labels/2010_000645.txt
#   inflating: labels/2010_000646.txt
#   inflating: labels/2010_000647.txt
#   inflating: labels/2010_000648.txt
#   inflating: labels/2010_000651.txt
#   inflating: labels/2010_000655.txt
#   inflating: labels/2010_000658.txt
#   inflating: labels/2010_000661.txt
#   inflating: labels/2010_000664.txt
#   inflating: labels/2010_000665.txt
#   inflating: labels/2010_000666.txt
#   inflating: labels/2010_000667.txt
#   inflating: labels/2010_000669.txt
#   inflating: labels/2010_000671.txt
#   inflating: labels/2010_000674.txt
#   inflating: labels/2010_000675.txt
#   inflating: labels/2010_000678.txt
#   inflating: labels/2010_000679.txt
#   inflating: labels/2010_000681.txt
#   inflating: labels/2010_000682.txt
#   inflating: labels/2010_000683.txt
#   inflating: labels/2010_000685.txt
#   inflating: labels/2010_000687.txt
#   inflating: labels/2010_000688.txt
#   inflating: labels/2010_000689.txt
#   inflating: labels/2010_000690.txt
#   inflating: labels/2010_000691.txt
#   inflating: labels/2010_000692.txt
#   inflating: labels/2010_000694.txt
#   inflating: labels/2010_000695.txt
#   inflating: labels/2010_000697.txt
#   inflating: labels/2010_000702.txt
#   inflating: labels/2010_000705.txt
#   inflating: labels/2010_000707.txt
#   inflating: labels/2010_000710.txt
#   inflating: labels/2010_000711.txt
#   inflating: labels/2010_000712.txt
#   inflating: labels/2010_000715.txt
#   inflating: labels/2010_000716.txt
#   inflating: labels/2010_000717.txt
#   inflating: labels/2010_000721.txt
#   inflating: labels/2010_000722.txt
#   inflating: labels/2010_000723.txt
#   inflating: labels/2010_000724.txt
#   inflating: labels/2010_000726.txt
#   inflating: labels/2010_000727.txt
#   inflating: labels/2010_000729.txt
#   inflating: labels/2010_000731.txt
#   inflating: labels/2010_000735.txt
#   inflating: labels/2010_000737.txt
#   inflating: labels/2010_000738.txt
#   inflating: labels/2010_000739.txt
#   inflating: labels/2010_000740.txt
#   inflating: labels/2010_000743.txt
#   inflating: labels/2010_000744.txt
#   inflating: labels/2010_000746.txt
#   inflating: labels/2010_000747.txt
#   inflating: labels/2010_000748.txt
#   inflating: labels/2010_000749.txt
#   inflating: labels/2010_000750.txt
#   inflating: labels/2010_000754.txt
#   inflating: labels/2010_000759.txt
#   inflating: labels/2010_000760.txt
#   inflating: labels/2010_000761.txt
#   inflating: labels/2010_000764.txt
#   inflating: labels/2010_000765.txt
#   inflating: labels/2010_000769.txt
#   inflating: labels/2010_000770.txt
#   inflating: labels/2010_000771.txt
#   inflating: labels/2010_000772.txt
#   inflating: labels/2010_000773.txt
#   inflating: labels/2010_000778.txt
#   inflating: labels/2010_000782.txt
#   inflating: labels/2010_000785.txt
#   inflating: labels/2010_000786.txt
#   inflating: labels/2010_000787.txt
#   inflating: labels/2010_000788.txt
#   inflating: labels/2010_000791.txt
#   inflating: labels/2010_000792.txt
#   inflating: labels/2010_000797.txt
#   inflating: labels/2010_000799.txt
#   inflating: labels/2010_000800.txt
#   inflating: labels/2010_000802.txt
#   inflating: labels/2010_000803.txt
#   inflating: labels/2010_000805.txt
#   inflating: labels/2010_000806.txt
#   inflating: labels/2010_000807.txt
#   inflating: labels/2010_000808.txt
#   inflating: labels/2010_000810.txt
#   inflating: labels/2010_000811.txt
#   inflating: labels/2010_000814.txt
#   inflating: labels/2010_000815.txt
#   inflating: labels/2010_000821.txt
#   inflating: labels/2010_000822.txt
#   inflating: labels/2010_000827.txt
#   inflating: labels/2010_000828.txt
#   inflating: labels/2010_000829.txt
#   inflating: labels/2010_000830.txt
#   inflating: labels/2010_000831.txt
#   inflating: labels/2010_000836.txt
#   inflating: labels/2010_000837.txt
#   inflating: labels/2010_000838.txt
#   inflating: labels/2010_000842.txt
#   inflating: labels/2010_000846.txt
#   inflating: labels/2010_000847.txt
#   inflating: labels/2010_000849.txt
#   inflating: labels/2010_000855.txt
#   inflating: labels/2010_000857.txt
#   inflating: labels/2010_000860.txt
#   inflating: labels/2010_000862.txt
#   inflating: labels/2010_000863.txt
#   inflating: labels/2010_000865.txt
#   inflating: labels/2010_000866.txt
#   inflating: labels/2010_000870.txt
#   inflating: labels/2010_000871.txt
#   inflating: labels/2010_000872.txt
#   inflating: labels/2010_000874.txt
#   inflating: labels/2010_000875.txt
#   inflating: labels/2010_000876.txt
#   inflating: labels/2010_000879.txt
#   inflating: labels/2010_000883.txt
#   inflating: labels/2010_000885.txt
#   inflating: labels/2010_000887.txt
#   inflating: labels/2010_000889.txt
#   inflating: labels/2010_000891.txt
#   inflating: labels/2010_000893.txt
#   inflating: labels/2010_000897.txt
#   inflating: labels/2010_000898.txt
#   inflating: labels/2010_000899.txt
#   inflating: labels/2010_000904.txt
#   inflating: labels/2010_000906.txt
#   inflating: labels/2010_000907.txt
#   inflating: labels/2010_000908.txt
#   inflating: labels/2010_000910.txt
#   inflating: labels/2010_000912.txt
#   inflating: labels/2010_000914.txt
#   inflating: labels/2010_000915.txt
#   inflating: labels/2010_000918.txt
#   inflating: labels/2010_000920.txt
#   inflating: labels/2010_000922.txt
#   inflating: labels/2010_000923.txt
#   inflating: labels/2010_000926.txt
#   inflating: labels/2010_000927.txt
#   inflating: labels/2010_000928.txt
#   inflating: labels/2010_000929.txt
#   inflating: labels/2010_000931.txt
#   inflating: labels/2010_000938.txt
#   inflating: labels/2010_000939.txt
#   inflating: labels/2010_000941.txt
#   inflating: labels/2010_000942.txt
#   inflating: labels/2010_000944.txt
#   inflating: labels/2010_000945.txt
#   inflating: labels/2010_000947.txt
#   inflating: labels/2010_000948.txt
#   inflating: labels/2010_000952.txt
#   inflating: labels/2010_000954.txt
#   inflating: labels/2010_000955.txt
#   inflating: labels/2010_000956.txt
#   inflating: labels/2010_000959.txt
#   inflating: labels/2010_000961.txt
#   inflating: labels/2010_000968.txt
#   inflating: labels/2010_000970.txt
#   inflating: labels/2010_000971.txt
#   inflating: labels/2010_000973.txt
#   inflating: labels/2010_000974.txt
#   inflating: labels/2010_000975.txt
#   inflating: labels/2010_000978.txt
#   inflating: labels/2010_000979.txt
#   inflating: labels/2010_000981.txt
#   inflating: labels/2010_000983.txt
#   inflating: labels/2010_000984.txt
#   inflating: labels/2010_000986.txt
#   inflating: labels/2010_000989.txt
#   inflating: labels/2010_000991.txt
#   inflating: labels/2010_000993.txt
#   inflating: labels/2010_000994.txt
#   inflating: labels/2010_000995.txt
#   inflating: labels/2010_000996.txt
#   inflating: labels/2010_001000.txt
#   inflating: labels/2010_001002.txt
#   inflating: labels/2010_001006.txt
#   inflating: labels/2010_001008.txt
#   inflating: labels/2010_001009.txt
#   inflating: labels/2010_001010.txt
#   inflating: labels/2010_001011.txt
#   inflating: labels/2010_001012.txt
#   inflating: labels/2010_001013.txt
#   inflating: labels/2010_001016.txt
#   inflating: labels/2010_001017.txt
#   inflating: labels/2010_001020.txt
#   inflating: labels/2010_001021.txt
#   inflating: labels/2010_001023.txt
#   inflating: labels/2010_001024.txt
#   inflating: labels/2010_001025.txt
#   inflating: labels/2010_001030.txt
#   inflating: labels/2010_001032.txt
#   inflating: labels/2010_001036.txt
#   inflating: labels/2010_001039.txt
#   inflating: labels/2010_001042.txt
#   inflating: labels/2010_001043.txt
#   inflating: labels/2010_001044.txt
#   inflating: labels/2010_001049.txt
#   inflating: labels/2010_001051.txt
#   inflating: labels/2010_001052.txt
#   inflating: labels/2010_001054.txt
#   inflating: labels/2010_001057.txt
#   inflating: labels/2010_001061.txt
#   inflating: labels/2010_001063.txt
#   inflating: labels/2010_001066.txt
#   inflating: labels/2010_001069.txt
#   inflating: labels/2010_001070.txt
#   inflating: labels/2010_001074.txt
#   inflating: labels/2010_001076.txt
#   inflating: labels/2010_001077.txt
#   inflating: labels/2010_001079.txt
#   inflating: labels/2010_001080.txt
#   inflating: labels/2010_001082.txt
#   inflating: labels/2010_001085.txt
#   inflating: labels/2010_001087.txt
#   inflating: labels/2010_001089.txt
#   inflating: labels/2010_001092.txt
#   inflating: labels/2010_001094.txt
#   inflating: labels/2010_001098.txt
#   inflating: labels/2010_001099.txt
#   inflating: labels/2010_001100.txt
#   inflating: labels/2010_001103.txt
#   inflating: labels/2010_001104.txt
#   inflating: labels/2010_001105.txt
#   inflating: labels/2010_001106.txt
#   inflating: labels/2010_001107.txt
#   inflating: labels/2010_001109.txt
#   inflating: labels/2010_001110.txt
#   inflating: labels/2010_001111.txt
#   inflating: labels/2010_001112.txt
#   inflating: labels/2010_001113.txt
#   inflating: labels/2010_001117.txt
#   inflating: labels/2010_001118.txt
#   inflating: labels/2010_001119.txt
#   inflating: labels/2010_001120.txt
#   inflating: labels/2010_001121.txt
#   inflating: labels/2010_001123.txt
#   inflating: labels/2010_001124.txt
#   inflating: labels/2010_001125.txt
#   inflating: labels/2010_001126.txt
#   inflating: labels/2010_001127.txt
#   inflating: labels/2010_001130.txt
#   inflating: labels/2010_001131.txt
#   inflating: labels/2010_001134.txt
#   inflating: labels/2010_001139.txt
#   inflating: labels/2010_001140.txt
#   inflating: labels/2010_001142.txt
#   inflating: labels/2010_001143.txt
#   inflating: labels/2010_001147.txt
#   inflating: labels/2010_001148.txt
#   inflating: labels/2010_001149.txt
#   inflating: labels/2010_001151.txt
#   inflating: labels/2010_001152.txt
#   inflating: labels/2010_001154.txt
#   inflating: labels/2010_001158.txt
#   inflating: labels/2010_001159.txt
#   inflating: labels/2010_001160.txt
#   inflating: labels/2010_001163.txt
#   inflating: labels/2010_001164.txt
#   inflating: labels/2010_001172.txt
#   inflating: labels/2010_001174.txt
#   inflating: labels/2010_001175.txt
#   inflating: labels/2010_001177.txt
#   inflating: labels/2010_001179.txt
#   inflating: labels/2010_001181.txt
#   inflating: labels/2010_001183.txt
#   inflating: labels/2010_001184.txt
#   inflating: labels/2010_001185.txt
#   inflating: labels/2010_001188.txt
#   inflating: labels/2010_001189.txt
#   inflating: labels/2010_001192.txt
#   inflating: labels/2010_001193.txt
#   inflating: labels/2010_001195.txt
#   inflating: labels/2010_001199.txt
#   inflating: labels/2010_001201.txt
#   inflating: labels/2010_001204.txt
#   inflating: labels/2010_001205.txt
#   inflating: labels/2010_001206.txt
#   inflating: labels/2010_001210.txt
#   inflating: labels/2010_001211.txt
#   inflating: labels/2010_001212.txt
#   inflating: labels/2010_001214.txt
#   inflating: labels/2010_001215.txt
#   inflating: labels/2010_001216.txt
#   inflating: labels/2010_001218.txt
#   inflating: labels/2010_001219.txt
#   inflating: labels/2010_001220.txt
#   inflating: labels/2010_001224.txt
#   inflating: labels/2010_001225.txt
#   inflating: labels/2010_001229.txt
#   inflating: labels/2010_001234.txt
#   inflating: labels/2010_001237.txt
#   inflating: labels/2010_001240.txt
#   inflating: labels/2010_001241.txt
#   inflating: labels/2010_001242.txt
#   inflating: labels/2010_001245.txt
#   inflating: labels/2010_001246.txt
#   inflating: labels/2010_001247.txt
#   inflating: labels/2010_001250.txt
#   inflating: labels/2010_001251.txt
#   inflating: labels/2010_001253.txt
#   inflating: labels/2010_001254.txt
#   inflating: labels/2010_001256.txt
#   inflating: labels/2010_001257.txt
#   inflating: labels/2010_001261.txt
#   inflating: labels/2010_001263.txt
#   inflating: labels/2010_001264.txt
#   inflating: labels/2010_001270.txt
#   inflating: labels/2010_001271.txt
#   inflating: labels/2010_001272.txt
#   inflating: labels/2010_001273.txt
#   inflating: labels/2010_001274.txt
#   inflating: labels/2010_001275.txt
#   inflating: labels/2010_001277.txt
#   inflating: labels/2010_001279.txt
#   inflating: labels/2010_001282.txt
#   inflating: labels/2010_001286.txt
#   inflating: labels/2010_001287.txt
#   inflating: labels/2010_001288.txt
#   inflating: labels/2010_001289.txt
#   inflating: labels/2010_001291.txt
#   inflating: labels/2010_001292.txt
#   inflating: labels/2010_001293.txt
#   inflating: labels/2010_001294.txt
#   inflating: labels/2010_001299.txt
#   inflating: labels/2010_001301.txt
#   inflating: labels/2010_001305.txt
#   inflating: labels/2010_001310.txt
#   inflating: labels/2010_001311.txt
#   inflating: labels/2010_001312.txt
#   inflating: labels/2010_001313.txt
#   inflating: labels/2010_001315.txt
#   inflating: labels/2010_001317.txt
#   inflating: labels/2010_001320.txt
#   inflating: labels/2010_001321.txt
#   inflating: labels/2010_001325.txt
#   inflating: labels/2010_001326.txt
#   inflating: labels/2010_001327.txt
#   inflating: labels/2010_001328.txt
#   inflating: labels/2010_001329.txt
#   inflating: labels/2010_001331.txt
#   inflating: labels/2010_001333.txt
#   inflating: labels/2010_001337.txt
#   inflating: labels/2010_001338.txt
#   inflating: labels/2010_001339.txt
#   inflating: labels/2010_001343.txt
#   inflating: labels/2010_001344.txt
#   inflating: labels/2010_001347.txt
#   inflating: labels/2010_001351.txt
#   inflating: labels/2010_001355.txt
#   inflating: labels/2010_001356.txt
#   inflating: labels/2010_001357.txt
#   inflating: labels/2010_001360.txt
#   inflating: labels/2010_001361.txt
#   inflating: labels/2010_001363.txt
#   inflating: labels/2010_001364.txt
#   inflating: labels/2010_001366.txt
#   inflating: labels/2010_001367.txt
#   inflating: labels/2010_001370.txt
#   inflating: labels/2010_001372.txt
#   inflating: labels/2010_001374.txt
#   inflating: labels/2010_001376.txt
#   inflating: labels/2010_001382.txt
#   inflating: labels/2010_001383.txt
#   inflating: labels/2010_001385.txt
#   inflating: labels/2010_001386.txt
#   inflating: labels/2010_001390.txt
#   inflating: labels/2010_001394.txt
#   inflating: labels/2010_001395.txt
#   inflating: labels/2010_001397.txt
#   inflating: labels/2010_001399.txt
#   inflating: labels/2010_001401.txt
#   inflating: labels/2010_001402.txt
#   inflating: labels/2010_001403.txt
#   inflating: labels/2010_001405.txt
#   inflating: labels/2010_001406.txt
#   inflating: labels/2010_001407.txt
#   inflating: labels/2010_001408.txt
#   inflating: labels/2010_001410.txt
#   inflating: labels/2010_001411.txt
#   inflating: labels/2010_001412.txt
#   inflating: labels/2010_001413.txt
#   inflating: labels/2010_001417.txt
#   inflating: labels/2010_001418.txt
#   inflating: labels/2010_001421.txt
#   inflating: labels/2010_001422.txt
#   inflating: labels/2010_001425.txt
#   inflating: labels/2010_001426.txt
#   inflating: labels/2010_001430.txt
#   inflating: labels/2010_001431.txt
#   inflating: labels/2010_001432.txt
#   inflating: labels/2010_001433.txt
#   inflating: labels/2010_001434.txt
#   inflating: labels/2010_001435.txt
#   inflating: labels/2010_001439.txt
#   inflating: labels/2010_001441.txt
#   inflating: labels/2010_001448.txt
#   inflating: labels/2010_001449.txt
#   inflating: labels/2010_001450.txt
#   inflating: labels/2010_001451.txt
#   inflating: labels/2010_001452.txt
#   inflating: labels/2010_001453.txt
#   inflating: labels/2010_001455.txt
#   inflating: labels/2010_001456.txt
#   inflating: labels/2010_001457.txt
#   inflating: labels/2010_001458.txt
#   inflating: labels/2010_001461.txt
#   inflating: labels/2010_001463.txt
#   inflating: labels/2010_001464.txt
#   inflating: labels/2010_001465.txt
#   inflating: labels/2010_001468.txt
#   inflating: labels/2010_001472.txt
#   inflating: labels/2010_001473.txt
#   inflating: labels/2010_001478.txt
#   inflating: labels/2010_001479.txt
#   inflating: labels/2010_001480.txt
#   inflating: labels/2010_001481.txt
#   inflating: labels/2010_001486.txt
#   inflating: labels/2010_001487.txt
#   inflating: labels/2010_001489.txt
#   inflating: labels/2010_001497.txt
#   inflating: labels/2010_001499.txt
#   inflating: labels/2010_001501.txt
#   inflating: labels/2010_001502.txt
#   inflating: labels/2010_001503.txt
#   inflating: labels/2010_001505.txt
#   inflating: labels/2010_001511.txt
#   inflating: labels/2010_001514.txt
#   inflating: labels/2010_001515.txt
#   inflating: labels/2010_001516.txt
#   inflating: labels/2010_001518.txt
#   inflating: labels/2010_001520.txt
#   inflating: labels/2010_001522.txt
#   inflating: labels/2010_001525.txt
#   inflating: labels/2010_001528.txt
#   inflating: labels/2010_001529.txt
#   inflating: labels/2010_001533.txt
#   inflating: labels/2010_001534.txt
#   inflating: labels/2010_001535.txt
#   inflating: labels/2010_001536.txt
#   inflating: labels/2010_001537.txt
#   inflating: labels/2010_001539.txt
#   inflating: labels/2010_001540.txt
#   inflating: labels/2010_001543.txt
#   inflating: labels/2010_001544.txt
#   inflating: labels/2010_001547.txt
#   inflating: labels/2010_001548.txt
#   inflating: labels/2010_001550.txt
#   inflating: labels/2010_001551.txt
#   inflating: labels/2010_001552.txt
#   inflating: labels/2010_001553.txt
#   inflating: labels/2010_001555.txt
#   inflating: labels/2010_001557.txt
#   inflating: labels/2010_001560.txt
# ...
#   inflating: labels/2011_002436.txt
#   inflating: labels/2011_002443.txt
#   inflating: labels/2011_002447.txt
#   inflating: labels/2011_002448.txt
#   inflating: labels/2011_002453.txt
#   inflating: labels/2011_002455.txt
#   inflating: labels/2011_002457.txt
#   inflating: labels/2011_002458.txt
#   inflating: labels/2011_002459.txt
#   inflating: labels/2011_002460.txt
#   inflating: labels/2011_002461.txt
#   inflating: labels/2011_002462.txt
#   inflating: labels/2011_002463.txt
#   inflating: labels/2011_002464.txt
#   inflating: labels/2011_002470.txt
#   inflating: labels/2011_002474.txt
#   inflating: labels/2011_002476.txt
#   inflating: labels/2011_002479.txt
#   inflating: labels/2011_002482.txt
#   inflating: labels/2011_002484.txt
#   inflating: labels/2011_002488.txt
#   inflating: labels/2011_002490.txt
#   inflating: labels/2011_002491.txt
#   inflating: labels/2011_002492.txt
#   inflating: labels/2011_002494.txt
#   inflating: labels/2011_002495.txt
#   inflating: labels/2011_002498.txt
#   inflating: labels/2011_002503.txt
#   inflating: labels/2011_002504.txt
#   inflating: labels/2011_002505.txt
#   inflating: labels/2011_002507.txt
#   inflating: labels/2011_002509.txt
#   inflating: labels/2011_002511.txt
#   inflating: labels/2011_002514.txt
#   inflating: labels/2011_002515.txt
#   inflating: labels/2011_002516.txt
#   inflating: labels/2011_002519.txt
#   inflating: labels/2011_002520.txt
#   inflating: labels/2011_002526.txt
#   inflating: labels/2011_002528.txt
#   inflating: labels/2011_002531.txt
#   inflating: labels/2011_002532.txt
#   inflating: labels/2011_002533.txt
#   inflating: labels/2011_002535.txt
#   inflating: labels/2011_002536.txt
#   inflating: labels/2011_002542.txt
#   inflating: labels/2011_002543.txt
#   inflating: labels/2011_002548.txt
#   inflating: labels/2011_002551.txt
#   inflating: labels/2011_002552.txt
#   inflating: labels/2011_002553.txt
#   inflating: labels/2011_002554.txt
#   inflating: labels/2011_002555.txt
#   inflating: labels/2011_002556.txt
#   inflating: labels/2011_002558.txt
#   inflating: labels/2011_002559.txt
#   inflating: labels/2011_002560.txt
#   inflating: labels/2011_002561.txt
#   inflating: labels/2011_002566.txt
#   inflating: labels/2011_002567.txt
#   inflating: labels/2011_002568.txt
#   inflating: labels/2011_002571.txt
#   inflating: labels/2011_002575.txt
#   inflating: labels/2011_002578.txt
#   inflating: labels/2011_002579.txt
#   inflating: labels/2011_002582.txt
#   inflating: labels/2011_002583.txt
#   inflating: labels/2011_002584.txt
#   inflating: labels/2011_002585.txt
#   inflating: labels/2011_002588.txt
#   inflating: labels/2011_002589.txt
#   inflating: labels/2011_002590.txt
#   inflating: labels/2011_002592.txt
#   inflating: labels/2011_002594.txt
#   inflating: labels/2011_002598.txt
#   inflating: labels/2011_002601.txt
#   inflating: labels/2011_002605.txt
#   inflating: labels/2011_002606.txt
#   inflating: labels/2011_002609.txt
#   inflating: labels/2011_002610.txt
#   inflating: labels/2011_002612.txt
#   inflating: labels/2011_002614.txt
#   inflating: labels/2011_002616.txt
#   inflating: labels/2011_002617.txt
#   inflating: labels/2011_002618.txt
#   inflating: labels/2011_002620.txt
#   inflating: labels/2011_002623.txt
#   inflating: labels/2011_002624.txt
#   inflating: labels/2011_002629.txt
#   inflating: labels/2011_002631.txt
#   inflating: labels/2011_002636.txt
#   inflating: labels/2011_002638.txt
#   inflating: labels/2011_002639.txt
#   inflating: labels/2011_002640.txt
#   inflating: labels/2011_002641.txt
#   inflating: labels/2011_002644.txt
#   inflating: labels/2011_002649.txt
#   inflating: labels/2011_002650.txt
#   inflating: labels/2011_002652.txt
#   inflating: labels/2011_002656.txt
#   inflating: labels/2011_002657.txt
#   inflating: labels/2011_002658.txt
#   inflating: labels/2011_002661.txt
#   inflating: labels/2011_002662.txt
#   inflating: labels/2011_002664.txt
#   inflating: labels/2011_002673.txt
#   inflating: labels/2011_002674.txt
#   inflating: labels/2011_002675.txt
#   inflating: labels/2011_002676.txt
#   inflating: labels/2011_002677.txt
#   inflating: labels/2011_002678.txt
#   inflating: labels/2011_002685.txt
#   inflating: labels/2011_002687.txt
#   inflating: labels/2011_002694.txt
#   inflating: labels/2011_002697.txt
#   inflating: labels/2011_002699.txt
#   inflating: labels/2011_002706.txt
#   inflating: labels/2011_002709.txt
#   inflating: labels/2011_002713.txt
#   inflating: labels/2011_002714.txt
#   inflating: labels/2011_002715.txt
#   inflating: labels/2011_002717.txt
#   inflating: labels/2011_002719.txt
#   inflating: labels/2011_002724.txt
#   inflating: labels/2011_002725.txt
#   inflating: labels/2011_002726.txt
#   inflating: labels/2011_002730.txt
#   inflating: labels/2011_002738.txt
#   inflating: labels/2011_002740.txt
#   inflating: labels/2011_002742.txt
#   inflating: labels/2011_002746.txt
#   inflating: labels/2011_002748.txt
#   inflating: labels/2011_002750.txt
#   inflating: labels/2011_002751.txt
#   inflating: labels/2011_002752.txt
#   inflating: labels/2011_002754.txt
#   inflating: labels/2011_002756.txt
#   inflating: labels/2011_002760.txt
#   inflating: labels/2011_002765.txt
#   inflating: labels/2011_002766.txt
#   inflating: labels/2011_002767.txt
#   inflating: labels/2011_002770.txt
#   inflating: labels/2011_002772.txt
#   inflating: labels/2011_002775.txt
#   inflating: labels/2011_002776.txt
#   inflating: labels/2011_002779.txt
#   inflating: labels/2011_002780.txt
#   inflating: labels/2011_002782.txt
#   inflating: labels/2011_002784.txt
#   inflating: labels/2011_002786.txt
#   inflating: labels/2011_002790.txt
#   inflating: labels/2011_002795.txt
#   inflating: labels/2011_002796.txt
#   inflating: labels/2011_002798.txt
#   inflating: labels/2011_002802.txt
#   inflating: labels/2011_002803.txt
#   inflating: labels/2011_002805.txt
#   inflating: labels/2011_002808.txt
#   inflating: labels/2011_002810.txt
#   inflating: labels/2011_002811.txt
#   inflating: labels/2011_002812.txt
#   inflating: labels/2011_002814.txt
#   inflating: labels/2011_002817.txt
#   inflating: labels/2011_002818.txt
#   inflating: labels/2011_002821.txt
#   inflating: labels/2011_002823.txt
#   inflating: labels/2011_002826.txt
#   inflating: labels/2011_002830.txt
#   inflating: labels/2011_002831.txt
#   inflating: labels/2011_002833.txt
#   inflating: labels/2011_002834.txt
#   inflating: labels/2011_002838.txt
#   inflating: labels/2011_002841.txt
#   inflating: labels/2011_002842.txt
#   inflating: labels/2011_002851.txt
#   inflating: labels/2011_002852.txt
#   inflating: labels/2011_002854.txt
#   inflating: labels/2011_002863.txt
#   inflating: labels/2011_002864.txt
#   inflating: labels/2011_002867.txt
#   inflating: labels/2011_002868.txt
#   inflating: labels/2011_002870.txt
#   inflating: labels/2011_002871.txt
#   inflating: labels/2011_002872.txt
#   inflating: labels/2011_002873.txt
#   inflating: labels/2011_002879.txt
#   inflating: labels/2011_002880.txt
#   inflating: labels/2011_002881.txt
#   inflating: labels/2011_002883.txt
#   inflating: labels/2011_002884.txt
#   inflating: labels/2011_002885.txt
#   inflating: labels/2011_002887.txt
#   inflating: labels/2011_002889.txt
#   inflating: labels/2011_002890.txt
#   inflating: labels/2011_002897.txt
#   inflating: labels/2011_002900.txt
#   inflating: labels/2011_002908.txt
#   inflating: labels/2011_002911.txt
#   inflating: labels/2011_002912.txt
#   inflating: labels/2011_002913.txt
#   inflating: labels/2011_002916.txt
#   inflating: labels/2011_002917.txt
#   inflating: labels/2011_002920.txt
#   inflating: labels/2011_002921.txt
#   inflating: labels/2011_002924.txt
#   inflating: labels/2011_002925.txt
#   inflating: labels/2011_002927.txt
#   inflating: labels/2011_002929.txt
#   inflating: labels/2011_002930.txt
#   inflating: labels/2011_002932.txt
#   inflating: labels/2011_002933.txt
#   inflating: labels/2011_002935.txt
#   inflating: labels/2011_002937.txt
#   inflating: labels/2011_002938.txt
#   inflating: labels/2011_002940.txt
#   inflating: labels/2011_002942.txt
#   inflating: labels/2011_002943.txt
#   inflating: labels/2011_002944.txt
#   inflating: labels/2011_002947.txt
#   inflating: labels/2011_002949.txt
#   inflating: labels/2011_002951.txt
#   inflating: labels/2011_002953.txt
#   inflating: labels/2011_002956.txt
#   inflating: labels/2011_002958.txt
#   inflating: labels/2011_002962.txt
#   inflating: labels/2011_002965.txt
#   inflating: labels/2011_002966.txt
#   inflating: labels/2011_002967.txt
#   inflating: labels/2011_002969.txt
#   inflating: labels/2011_002970.txt
#   inflating: labels/2011_002971.txt
#   inflating: labels/2011_002974.txt
#   inflating: labels/2011_002975.txt
#   inflating: labels/2011_002978.txt
#   inflating: labels/2011_002979.txt
#   inflating: labels/2011_002983.txt
#   inflating: labels/2011_002985.txt
#   inflating: labels/2011_002987.txt
#   inflating: labels/2011_002988.txt
#   inflating: labels/2011_002992.txt
#   inflating: labels/2011_002993.txt
#   inflating: labels/2011_002994.txt
#   inflating: labels/2011_002997.txt
#   inflating: labels/2011_002999.txt
#   inflating: labels/2011_003002.txt
#   inflating: labels/2011_003003.txt
#   inflating: labels/2011_003005.txt
#   inflating: labels/2011_003010.txt
#   inflating: labels/2011_003011.txt
#   inflating: labels/2011_003012.txt
#   inflating: labels/2011_003013.txt
#   inflating: labels/2011_003016.txt
#   inflating: labels/2011_003019.txt
#   inflating: labels/2011_003020.txt
#   inflating: labels/2011_003023.txt
#   inflating: labels/2011_003025.txt
#   inflating: labels/2011_003027.txt
#   inflating: labels/2011_003028.txt
#   inflating: labels/2011_003029.txt
#   inflating: labels/2011_003030.txt
#   inflating: labels/2011_003034.txt
#   inflating: labels/2011_003038.txt
#   inflating: labels/2011_003039.txt
#   inflating: labels/2011_003041.txt
#   inflating: labels/2011_003043.txt
#   inflating: labels/2011_003044.txt
#   inflating: labels/2011_003047.txt
#   inflating: labels/2011_003048.txt
#   inflating: labels/2011_003049.txt
#   inflating: labels/2011_003050.txt
#   inflating: labels/2011_003054.txt
#   inflating: labels/2011_003055.txt
#   inflating: labels/2011_003057.txt
#   inflating: labels/2011_003059.txt
#   inflating: labels/2011_003063.txt
#   inflating: labels/2011_003065.txt
#   inflating: labels/2011_003066.txt
#   inflating: labels/2011_003073.txt
#   inflating: labels/2011_003074.txt
#   inflating: labels/2011_003076.txt
#   inflating: labels/2011_003078.txt
#   inflating: labels/2011_003079.txt
#   inflating: labels/2011_003081.txt
#   inflating: labels/2011_003085.txt
#   inflating: labels/2011_003086.txt
#   inflating: labels/2011_003089.txt
#   inflating: labels/2011_003091.txt
#   inflating: labels/2011_003097.txt
#   inflating: labels/2011_003098.txt
#   inflating: labels/2011_003103.txt
#   inflating: labels/2011_003109.txt
#   inflating: labels/2011_003111.txt
#   inflating: labels/2011_003114.txt
#   inflating: labels/2011_003115.txt
#   inflating: labels/2011_003121.txt
#   inflating: labels/2011_003124.txt
#   inflating: labels/2011_003132.txt
#   inflating: labels/2011_003134.txt
#   inflating: labels/2011_003138.txt
#   inflating: labels/2011_003141.txt
#   inflating: labels/2011_003145.txt
#   inflating: labels/2011_003146.txt
#   inflating: labels/2011_003148.txt
#   inflating: labels/2011_003149.txt
#   inflating: labels/2011_003150.txt
#   inflating: labels/2011_003151.txt
#   inflating: labels/2011_003152.txt
#   inflating: labels/2011_003154.txt
#   inflating: labels/2011_003158.txt
#   inflating: labels/2011_003159.txt
#   inflating: labels/2011_003162.txt
#   inflating: labels/2011_003163.txt
#   inflating: labels/2011_003166.txt
#   inflating: labels/2011_003167.txt
#   inflating: labels/2011_003168.txt
#   inflating: labels/2011_003169.txt
#   inflating: labels/2011_003171.txt
#   inflating: labels/2011_003176.txt
#   inflating: labels/2011_003177.txt
#   inflating: labels/2011_003182.txt
#   inflating: labels/2011_003183.txt
#   inflating: labels/2011_003184.txt
#   inflating: labels/2011_003185.txt
#   inflating: labels/2011_003187.txt
#   inflating: labels/2011_003188.txt
#   inflating: labels/2011_003192.txt
#   inflating: labels/2011_003194.txt
#   inflating: labels/2011_003197.txt
#   inflating: labels/2011_003201.txt
#   inflating: labels/2011_003205.txt
#   inflating: labels/2011_003207.txt
#   inflating: labels/2011_003211.txt
#   inflating: labels/2011_003212.txt
#   inflating: labels/2011_003213.txt
#   inflating: labels/2011_003216.txt
#   inflating: labels/2011_003220.txt
#   inflating: labels/2011_003223.txt
#   inflating: labels/2011_003228.txt
#   inflating: labels/2011_003230.txt
#   inflating: labels/2011_003232.txt
#   inflating: labels/2011_003236.txt
#   inflating: labels/2011_003238.txt
#   inflating: labels/2011_003240.txt
#   inflating: labels/2011_003242.txt
#   inflating: labels/2011_003244.txt
#   inflating: labels/2011_003246.txt
#   inflating: labels/2011_003247.txt
#   inflating: labels/2011_003253.txt
#   inflating: labels/2011_003254.txt
#   inflating: labels/2011_003255.txt
#   inflating: labels/2011_003256.txt
#   inflating: labels/2011_003259.txt
#   inflating: labels/2011_003260.txt
#   inflating: labels/2011_003261.txt
#   inflating: labels/2011_003262.txt
#   inflating: labels/2011_003269.txt
#   inflating: labels/2011_003271.txt
#   inflating: labels/2011_003274.txt
#   inflating: labels/2011_003275.txt
#   inflating: labels/2011_003276.txt
#   inflating: test.csv
#   inflating: train.csv
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.16.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.6)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2024.8.30)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Failed to retrieve file url:
#
# 	Cannot retrieve the public link of the file. You may need to change
# 	the permission to 'Anyone with the link', or have had many accesses.
# 	Check FAQ in https://github.com/wkentaro/gdown?tab=readme-ov-file#faq.
#
# You may still be able to access the file from the browser:
#
# 	https://drive.google.com/uc?id=FILE_ID
#
# but Gdown can't. Please check connections and permissions.
# Archive:  PASCAL_VOC.zip
# replace 100examples.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: 100examples.csv
# replace 1examples.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: 100examples.csv  2examples.csv	images	PASCAL_VOC.zip	train.csv
# 1examples.csv	 8examples.csv	labels	test.csv

# %%
# ---------------------------       Main script for training YOLO model on Pascal VOC dataset    -----------------------------

import torch
import torchvision.transforms as transforms
import torch.optim as optim
import torchvision.transforms.functional as FT
from tqdm import tqdm
from torch.utils.data import DataLoader
from torch.utils.data import Subset
import random
from typing import List

#random seed for reproducibility
RANDOM_SEED = 123
torch.manual_seed(RANDOM_SEED)


# Pascal VOC dataset classes
VOC_CLASSES = [
    "aeroplane", "bicycle", "bird", "boat", "bottle", "bus", "car", "cat",
    "chair", "cow", "diningtable", "dog", "horse", "motorbike", "person",
    "pottedplant", "sheep", "sofa", "train", "tvmonitor"
]


# Training configurations
CONFIG = {
    "LEARNING_RATE": 2e-5,
    "DEVICE": "cpu",  # we have used "cpu" only
    "BATCH_SIZE": 16,
    "WEIGHT_DECAY": 0,
    "EPOCHS": 1000,  #5 - in the output panel the code run was with 10 epochs and only on 1000 data
    "NUM_WORKERS": 2,
    "PIN_MEMORY": True,
    "LOAD_MODEL": False,
    "LOAD_MODEL_FILE": "/content/CS512_YOLO.pth.tar",
    "IMG_DIR": "/root/.cache/kagglehub/datasets/aladdinpersson/pascal-voc-dataset-used-in-yolov3-video/versions/1/PASCAL_VOC/images",
    "LABEL_DIR": "/root/.cache/kagglehub/datasets/aladdinpersson/pascal-voc-dataset-used-in-yolov3-video/versions/1/PASCAL_VOC/labels",
}


class Compose(object):
    def __init__(self, transforms):
        self.transforms = transforms

    def __call__(self, img, bboxes):
        for t in self.transforms:
            img, bboxes = t(img), bboxes

        return img, bboxes

# Defining image transformations
transform = Compose([transforms.Resize((448, 448)), transforms.ToTensor(),])


def train_epoch(train_loader, model, optimizer, loss_fn):
    """
    Trains the model for one epoch
    """
    model.train()
    progress_bar = tqdm(train_loader, leave=True)
    epoch_losses = []

    for batch_idx, (images, targets) in enumerate(progress_bar):
        images, targets = images.to(CONFIG["DEVICE"]), targets.to(CONFIG["DEVICE"])

        predictions = model(images)
        loss = loss_fn(predictions, targets)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        epoch_losses.append(loss.item())
        progress_bar.set_postfix(loss=loss.item())

    mean_loss = sum(epoch_losses) / len(epoch_losses)
    print(f"Mean loss for this epoch: {mean_loss:.4f}")


def main():
    # Initializing model, optimizer, and loss function
    model = YoloVersion1(split_size=7, num_boxes=2, num_classes=20).to(CONFIG["DEVICE"])
    optimizer = optim.Adam(
        model.parameters(), lr=CONFIG["LEARNING_RATE"], weight_decay=CONFIG["WEIGHT_DECAY"]
    )
    loss_fn = YoloLoss()

    if CONFIG["LOAD_MODEL"]:
        load_checkpoint(torch.load(CONFIG["LOAD_MODEL_FILE"]), model, optimizer)

    # Loading and preparing datasets
    train_dataset = VOCDataset(
        "/root/.cache/kagglehub/datasets/aladdinpersson/pascal-voc-dataset-used-in-yolov3-video/versions/1/PASCAL_VOC/train.csv",
        transform=transform,
        image_dir=CONFIG["IMG_DIR"],
        label_dir=CONFIG["LABEL_DIR"],
    )

    # subset of the training data (1000 samples)
    #train_dataset = Subset(train_dataset, random.sample(range(len(train_dataset)), 1000))

    test_dataset = VOCDataset(
        "/root/.cache/kagglehub/datasets/aladdinpersson/pascal-voc-dataset-used-in-yolov3-video/versions/1/PASCAL_VOC/test.csv",
        transform=transform,
        image_dir=CONFIG["IMG_DIR"],
        label_dir=CONFIG["LABEL_DIR"],
    )

    # Data loaders
    train_loader = DataLoader(
        dataset=train_dataset,
        batch_size=CONFIG["BATCH_SIZE"],
        num_workers=CONFIG["NUM_WORKERS"],
        pin_memory=CONFIG["PIN_MEMORY"],
        shuffle=True,
        drop_last=False,
    )

    test_loader = DataLoader(
        dataset=test_dataset,
        batch_size=CONFIG["BATCH_SIZE"],
        num_workers=CONFIG["NUM_WORKERS"],
        pin_memory=CONFIG["PIN_MEMORY"],
        shuffle=True,
        drop_last=True,
    )

    # Training loop
    for epoch in range(CONFIG["EPOCHS"]):
        ##############################################################################
        # The code below test the model performance using 8 photos
        # LOAD_MODEL = true, the code will load the model
        if CONFIG["LOAD_MODEL"]:
            for x, y in train_loader:
                x = x.to(CONFIG["DEVICE"])
                for idx in range(8):
                    bboxes = convert_yolo_output_to_boxes(model(x))
                    bboxes = non_max_suppression(bboxes[idx], iou_threshold=0.5, confidence_threshold=0.4, box_format="midpoint")
                    #plot_image(x[idx].permute(1,2,0).to("cpu"), bboxes)

                    # Extract class predictions
                    class_preds = [box[0] for box in bboxes]

                    # Convert class indices to labels (assuming you have a list of class names)
                    class_labels = [VOC_CLASSES[int(pred)] for pred in class_preds]

                    # Plot image with bounding boxes and class labels
                    plot_image(x[idx].permute(1,2,0).to("cpu"), bboxes, class_labels)

            import sys
            sys.exit()
        ##########################################################################################

        # train the model
        train_epoch(train_loader, model, optimizer, loss_fn)

        # Evaluating the model
        pred_boxes, target_boxes = extract_bounding_boxes(
            train_loader, model, iou_threshold=0.1, threshold=0.05
        )

        # Calculation mAP
        mean_avg_prec = calculate_mean_average_precision(
            pred_boxes,
            target_boxes,
            iou_threshold=0.1,
            box_format="midpoint"
        )
        print(f"Epoch {epoch+1}/{CONFIG['EPOCHS']} - Train mAP: {mean_avg_prec:.4f}")


        # Save checkpoint after each epoch (optional)
        checkpoint = {
            "state_dict": model.state_dict(),
            "optimizer": optimizer.state_dict(),
        }
        save_checkpoint(checkpoint, filename=CONFIG["LOAD_MODEL_FILE"])


if __name__ == "__main__":
    main()
# Out:
# 100%|██████████| 63/63 [01:29<00:00,  1.42s/it, loss=201]
# Mean loss for this epoch: 549.2892
# Epoch 1/10 - Train mAP: 0.0070
# => Saving checkpoint
# 100%|██████████| 63/63 [01:34<00:00,  1.50s/it, loss=196]
# Mean loss for this epoch: 292.4213
# Epoch 2/10 - Train mAP: 0.0153
# => Saving checkpoint
# 100%|██████████| 63/63 [01:34<00:00,  1.50s/it, loss=121]
# Mean loss for this epoch: 210.4699
# Epoch 3/10 - Train mAP: 0.0289
# => Saving checkpoint
# 100%|██████████| 63/63 [01:43<00:00,  1.64s/it, loss=89.2]
# Mean loss for this epoch: 176.1152
# Epoch 4/10 - Train mAP: 0.0759
# => Saving checkpoint
# 100%|██████████| 63/63 [01:44<00:00,  1.66s/it, loss=71.2]
# Mean loss for this epoch: 156.5019
# Epoch 5/10 - Train mAP: 0.1279
# => Saving checkpoint
# 100%|██████████| 63/63 [01:43<00:00,  1.65s/it, loss=85.7]
# Mean loss for this epoch: 144.6685
# Epoch 6/10 - Train mAP: 0.1874
# => Saving checkpoint
# 100%|██████████| 63/63 [01:39<00:00,  1.59s/it, loss=76.3]
# Mean loss for this epoch: 133.3275
# Epoch 7/10 - Train mAP: 0.2325
# => Saving checkpoint
# 100%|██████████| 63/63 [01:45<00:00,  1.67s/it, loss=71.1]
# Mean loss for this epoch: 122.8571
# Epoch 8/10 - Train mAP: 0.3880
# => Saving checkpoint
# 100%|██████████| 63/63 [01:41<00:00,  1.62s/it, loss=94.2]
# Mean loss for this epoch: 115.4267
# Epoch 9/10 - Train mAP: 0.4722
# => Saving checkpoint
# 100%|██████████| 63/63 [01:41<00:00,  1.61s/it, loss=85.7]
# Mean loss for this epoch: 110.0101
# Epoch 10/10 - Train mAP: 0.4974
# => Saving checkpoint
